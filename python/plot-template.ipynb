# %%
import matplotlib.pyplot as plt

print(plt.rcParams.keys())
# Out:
# KeysView(RcParams({'_internal.classic_mode': False,
#           'agg.path.chunksize': 0,
#           'animation.bitrate': -1,
#           'animation.codec': 'h264',
#           'animation.convert_args': ['-layers', 'OptimizePlus'],
#           'animation.convert_path': 'convert',
#           'animation.embed_limit': 20.0,
#           'animation.ffmpeg_args': [],
#           'animation.ffmpeg_path': 'ffmpeg',
#           'animation.frame_format': 'png',
#           'animation.html': 'none',
#           'animation.writer': 'ffmpeg',
#           'axes.autolimit_mode': 'data',
#           'axes.axisbelow': 'line',
#           'axes.edgecolor': 'black',
#           'axes.facecolor': 'white',
#           'axes.formatter.limits': [-5, 6],
#           'axes.formatter.min_exponent': 0,
#           'axes.formatter.offset_threshold': 4,
#           'axes.formatter.use_locale': False,
#           'axes.formatter.use_mathtext': False,
#           'axes.formatter.useoffset': True,
#           'axes.grid': False,
#           'axes.grid.axis': 'both',
#           'axes.grid.which': 'major',
#           'axes.labelcolor': 'black',
#           'axes.labelpad': 4.0,
#           'axes.labelsize': 'medium',
#           'axes.labelweight': 'normal',
#           'axes.linewidth': 0.8,
#           'axes.prop_cycle': cycler('color', ['#1f77b4', '#ff7f0e', '#2ca02c', '#d62728', '#9467bd', '#8c564b', '#e377c2', '#7f7f7f', '#bcbd22', '#17becf']),
#           'axes.spines.bottom': True,
#           'axes.spines.left': True,
#           'axes.spines.right': True,
#           'axes.spines.top': True,
#           'axes.titlecolor': 'auto',
#           'axes.titlelocation': 'center',
#           'axes.titlepad': 6.0,
#           'axes.titlesize': 'large',
#           'axes.titleweight': 'normal',
#           'axes.titley': None,
#           'axes.unicode_minus': True,
#           'axes.xmargin': 0.05,
#           'axes.ymargin': 0.05,
#           'axes.zmargin': 0.05,
#           'axes3d.automargin': False,
#           'axes3d.grid': True,
#           'axes3d.mouserotationstyle': 'arcball',
#           'axes3d.trackballborder': 0.2,
#           'axes3d.trackballsize': 0.667,
#           'axes3d.xaxis.panecolor': (0.95, 0.95, 0.95, 0.5),
#           'axes3d.yaxis.panecolor': (0.9, 0.9, 0.9, 0.5),
#           'axes3d.zaxis.panecolor': (0.925, 0.925, 0.925, 0.5),
#           'backend': 'module://matplotlib_inline.backend_inline',
#           'backend_fallback': True,
#           'boxplot.bootstrap': None,
#           'boxplot.boxprops.color': 'black',
#           'boxplot.boxprops.linestyle': '-',
#           'boxplot.boxprops.linewidth': 1.0,
#           'boxplot.capprops.color': 'black',
#           'boxplot.capprops.linestyle': '-',
#           'boxplot.capprops.linewidth': 1.0,
#           'boxplot.flierprops.color': 'black',
#           'boxplot.flierprops.linestyle': 'none',
#           'boxplot.flierprops.linewidth': 1.0,
#           'boxplot.flierprops.marker': 'o',
#           'boxplot.flierprops.markeredgecolor': 'black',
#           'boxplot.flierprops.markeredgewidth': 1.0,
#           'boxplot.flierprops.markerfacecolor': 'none',
#           'boxplot.flierprops.markersize': 6.0,
#           'boxplot.meanline': False,
#           'boxplot.meanprops.color': 'C2',
#           'boxplot.meanprops.linestyle': '--',
#           'boxplot.meanprops.linewidth': 1.0,
#           'boxplot.meanprops.marker': '^',
#           'boxplot.meanprops.markeredgecolor': 'C2',
#           'boxplot.meanprops.markerfacecolor': 'C2',
#           'boxplot.meanprops.markersize': 6.0,
#           'boxplot.medianprops.color': 'C1',
#           'boxplot.medianprops.linestyle': '-',
#           'boxplot.medianprops.linewidth': 1.0,
#           'boxplot.notch': False,
#           'boxplot.patchartist': False,
#           'boxplot.showbox': True,
#           'boxplot.showcaps': True,
#           'boxplot.showfliers': True,
#           'boxplot.showmeans': False,
#           'boxplot.vertical': True,
#           'boxplot.whiskerprops.color': 'black',
#           'boxplot.whiskerprops.linestyle': '-',
#           'boxplot.whiskerprops.linewidth': 1.0,
#           'boxplot.whiskers': 1.5,
#           'contour.algorithm': 'mpl2014',
#           'contour.corner_mask': True,
#           'contour.linewidth': None,
#           'contour.negative_linestyle': 'dashed',
#           'date.autoformatter.day': '%Y-%m-%d',
#           'date.autoformatter.hour': '%m-%d %H',
#           'date.autoformatter.microsecond': '%M:%S.%f',
#           'date.autoformatter.minute': '%d %H:%M',
#           'date.autoformatter.month': '%Y-%m',
#           'date.autoformatter.second': '%H:%M:%S',
#           'date.autoformatter.year': '%Y',
#           'date.converter': 'auto',
#           'date.epoch': '1970-01-01T00:00:00',
#           'date.interval_multiples': True,
#           'docstring.hardcopy': False,
#           'errorbar.capsize': 0.0,
#           'figure.autolayout': False,
#           'figure.constrained_layout.h_pad': 0.04167,
#           'figure.constrained_layout.hspace': 0.02,
#           'figure.constrained_layout.use': False,
#           'figure.constrained_layout.w_pad': 0.04167,
#           'figure.constrained_layout.wspace': 0.02,
#           'figure.dpi': 100.0,
#           'figure.edgecolor': 'white',
#           'figure.facecolor': 'white',
#           'figure.figsize': [6.4, 4.8],
#           'figure.frameon': True,
#           'figure.hooks': [],
#           'figure.labelsize': 'large',
#           'figure.labelweight': 'normal',
#           'figure.max_open_warning': 20,
#           'figure.raise_window': True,
#           'figure.subplot.bottom': 0.11,
#           'figure.subplot.hspace': 0.2,
#           'figure.subplot.left': 0.125,
#           'figure.subplot.right': 0.9,
#           'figure.subplot.top': 0.88,
#           'figure.subplot.wspace': 0.2,
#           'figure.titlesize': 'large',
#           'figure.titleweight': 'normal',
#           'font.cursive': ['Apple Chancery',
#                            'Textile',
#                            'Zapf Chancery',
#                            'Sand',
#                            'Script MT',
#                            'Felipa',
#                            'Comic Neue',
#                            'Comic Sans MS',
#                            'cursive'],
#           'font.family': ['sans-serif'],
#           'font.fantasy': ['Chicago',
#                            'Charcoal',
#                            'Impact',
#                            'Western',
#                            'xkcd script',
#                            'fantasy'],
#           'font.monospace': ['DejaVu Sans Mono',
#                              'Bitstream Vera Sans Mono',
#                              'Computer Modern Typewriter',
#                              'Andale Mono',
#                              'Nimbus Mono L',
#                              'Courier New',
#                              'Courier',
#                              'Fixed',
#                              'Terminal',
#                              'monospace'],
#           'font.sans-serif': ['DejaVu Sans',
#                               'Bitstream Vera Sans',
#                               'Computer Modern Sans Serif',
#                               'Lucida Grande',
#                               'Verdana',
#                               'Geneva',
#                               'Lucid',
#                               'Arial',
#                               'Helvetica',
#                               'Avant Garde',
#                               'sans-serif'],
#           'font.serif': ['DejaVu Serif',
#                          'Bitstream Vera Serif',
#                          'Computer Modern Roman',
#                          'New Century Schoolbook',
#                          'Century Schoolbook L',
#                          'Utopia',
#                          'ITC Bookman',
#                          'Bookman',
#                          'Nimbus Roman No9 L',
#                          'Times New Roman',
#                          'Times',
#                          'Palatino',
#                          'Charter',
#                          'serif'],
#           'font.size': 10.0,
#           'font.stretch': 'normal',
#           'font.style': 'normal',
#           'font.variant': 'normal',
#           'font.weight': 'normal',
#           'grid.alpha': 1.0,
#           'grid.color': '#b0b0b0',
#           'grid.linestyle': '-',
#           'grid.linewidth': 0.8,
#           'hatch.color': 'black',
#           'hatch.linewidth': 1.0,
#           'hist.bins': 10,
#           'image.aspect': 'equal',
#           'image.cmap': 'viridis',
#           'image.composite_image': True,
#           'image.interpolation': 'auto',
#           'image.interpolation_stage': 'auto',
#           'image.lut': 256,
#           'image.origin': 'upper',
#           'image.resample': True,
#           'interactive': False,
#           'keymap.back': ['left', 'c', 'backspace', 'MouseButton.BACK'],
#           'keymap.copy': ['ctrl+c', 'cmd+c'],
#           'keymap.forward': ['right', 'v', 'MouseButton.FORWARD'],
#           'keymap.fullscreen': ['f', 'ctrl+f'],
#           'keymap.grid': ['g'],
#           'keymap.grid_minor': ['G'],
#           'keymap.help': ['f1'],
#           'keymap.home': ['h', 'r', 'home'],
#           'keymap.pan': ['p'],
#           'keymap.quit': ['ctrl+w', 'cmd+w', 'q'],
#           'keymap.quit_all': [],
#           'keymap.save': ['s', 'ctrl+s'],
#           'keymap.xscale': ['k', 'L'],
#           'keymap.yscale': ['l'],
#           'keymap.zoom': ['o'],
#           'legend.borderaxespad': 0.5,
#           'legend.borderpad': 0.4,
#           'legend.columnspacing': 2.0,
#           'legend.edgecolor': '0.8',
#           'legend.facecolor': 'inherit',
#           'legend.fancybox': True,
#           'legend.fontsize': 'medium',
#           'legend.framealpha': 0.8,
#           'legend.frameon': True,
#           'legend.handleheight': 0.7,
#           'legend.handlelength': 2.0,
#           'legend.handletextpad': 0.8,
#           'legend.labelcolor': 'None',
#           'legend.labelspacing': 0.5,
#           'legend.loc': 'best',
#           'legend.markerscale': 1.0,
#           'legend.numpoints': 1,
#           'legend.scatterpoints': 1,
#           'legend.shadow': False,
#           'legend.title_fontsize': None,
#           'lines.antialiased': True,
#           'lines.color': 'C0',
#           'lines.dash_capstyle': <CapStyle.butt: 'butt'>,
#           'lines.dash_joinstyle': <JoinStyle.round: 'round'>,
#           'lines.dashdot_pattern': [6.4, 1.6, 1.0, 1.6],
#           'lines.dashed_pattern': [3.7, 1.6],
#           'lines.dotted_pattern': [1.0, 1.65],
#           'lines.linestyle': '-',
#           'lines.linewidth': 1.5,
#           'lines.marker': 'None',
#           'lines.markeredgecolor': 'auto',
#           'lines.markeredgewidth': 1.0,
#           'lines.markerfacecolor': 'auto',
#           'lines.markersize': 6.0,
#           'lines.scale_dashes': True,
#           'lines.solid_capstyle': <CapStyle.projecting: 'projecting'>,
#           'lines.solid_joinstyle': <JoinStyle.round: 'round'>,
#           'macosx.window_mode': 'system',
#           'markers.fillstyle': 'full',
#           'mathtext.bf': 'sans:bold',
#           'mathtext.bfit': 'sans:italic:bold',
#           'mathtext.cal': 'cursive',
#           'mathtext.default': 'it',
#           'mathtext.fallback': 'cm',
#           'mathtext.fontset': 'dejavusans',
#           'mathtext.it': 'sans:italic',
#           'mathtext.rm': 'sans',
#           'mathtext.sf': 'sans',
#           'mathtext.tt': 'monospace',
#           'patch.antialiased': True,
#           'patch.edgecolor': 'black',
#           'patch.facecolor': 'C0',
#           'patch.force_edgecolor': False,
#           'patch.linewidth': 1.0,
#           'path.effects': [],
#           'path.simplify': True,
#           'path.simplify_threshold': 0.111111111111,
#           'path.sketch': None,
#           'path.snap': True,
#           'pcolor.shading': 'auto',
#           'pcolormesh.snap': True,
#           'pdf.compression': 6,
#           'pdf.fonttype': 3,
#           'pdf.inheritcolor': False,
#           'pdf.use14corefonts': False,
#           'pgf.preamble': '',
#           'pgf.rcfonts': True,
#           'pgf.texsystem': 'xelatex',
#           'polaraxes.grid': True,
#           'ps.distiller.res': 6000,
#           'ps.fonttype': 3,
#           'ps.papersize': 'letter',
#           'ps.useafm': False,
#           'ps.usedistiller': None,
#           'savefig.bbox': None,
#           'savefig.directory': '~',
#           'savefig.dpi': 'figure',
#           'savefig.edgecolor': 'auto',
#           'savefig.facecolor': 'auto',
#           'savefig.format': 'png',
#           'savefig.orientation': 'portrait',
#           'savefig.pad_inches': 0.1,
#           'savefig.transparent': False,
#           'scatter.edgecolors': 'face',
#           'scatter.marker': 'o',
#           'svg.fonttype': 'path',
#           'svg.hashsalt': None,
#           'svg.id': None,
#           'svg.image_inline': True,
#           'text.antialiased': True,
#           'text.color': 'black',
#           'text.hinting': 'force_autohint',
#           'text.hinting_factor': 8,
#           'text.kerning_factor': 0,
#           'text.latex.preamble': '',
#           'text.parse_math': True,
#           'text.usetex': False,
#           'timezone': 'UTC',
#           'tk.window_focus': False,
#           'toolbar': 'toolbar2',
#           'webagg.address': '127.0.0.1',
#           'webagg.open_in_browser': True,
#           'webagg.port': 8988,
#           'webagg.port_retries': 50,
#           'xaxis.labellocation': 'center',
#           'xtick.alignment': 'center',
#           'xtick.bottom': True,
#           'xtick.color': 'black',
#           'xtick.direction': 'out',
#           'xtick.labelbottom': True,
#           'xtick.labelcolor': 'inherit',
#           'xtick.labelsize': 'medium',
#           'xtick.labeltop': False,
#           'xtick.major.bottom': True,
#           'xtick.major.pad': 3.5,
#           'xtick.major.size': 3.5,
#           'xtick.major.top': True,
#           'xtick.major.width': 0.8,
#           'xtick.minor.bottom': True,
#           'xtick.minor.ndivs': 'auto',
#           'xtick.minor.pad': 3.4,
#           'xtick.minor.size': 2.0,
#           'xtick.minor.top': True,
#           'xtick.minor.visible': False,
#           'xtick.minor.width': 0.6,
#           'xtick.top': False,
#           'yaxis.labellocation': 'center',
#           'ytick.alignment': 'center_baseline',
#           'ytick.color': 'black',
#           'ytick.direction': 'out',
#           'ytick.labelcolor': 'inherit',
#           'ytick.labelleft': True,
#           'ytick.labelright': False,
#           'ytick.labelsize': 'medium',
#           'ytick.left': True,
#           'ytick.major.left': True,
#           'ytick.major.pad': 3.5,
#           'ytick.major.right': True,
#           'ytick.major.size': 3.5,
#           'ytick.major.width': 0.8,
#           'ytick.minor.left': True,
#           'ytick.minor.ndivs': 'auto',
#           'ytick.minor.pad': 3.4,
#           'ytick.minor.right': True,
#           'ytick.minor.size': 2.0,
#           'ytick.minor.visible': False,
#           'ytick.minor.width': 0.6,
#           'ytick.right': False}))

# %%
import matplotlib.font_manager as fm

font_paths = fm.findSystemFonts()

print(f"共找到{len(font_paths)}个字体文件")
for path in font_paths:
    font_prop = fm.FontProperties(fname=path)
    font_name = font_prop.get_name()
    print(path)
    print(font_name)

# print(fm.fontManager.ttflist)
# Out:
# 共找到5301个字体文件
# /usr/share/fonts/noto/NotoSansKannada-ExtraCondensedBlack.ttf
# Noto Sans Kannada
# /usr/share/fonts/OTF/OverpassNerdFont-Light.otf
# Overpass Nerd Font
# /usr/share/fonts/TTF/JetBrainsMonoNLNerdFontMono-ExtraLightItalic.ttf
# JetBrainsMonoNL NFM
# /usr/share/fonts/noto/NotoSerifDisplay-Thin.ttf
# Noto Serif Display
# /usr/share/fonts/noto/NotoSansKhmer-ExtraCondensedLight.ttf
# Noto Sans Khmer
# /usr/share/fonts/TTF/CaskaydiaMonoNerdFont-Light.ttf
# CaskaydiaMono NF
# /usr/share/fonts/wps-fonts/calibri.ttf
# Calibri
# /usr/share/fonts/TTF/RecMonoLinearNerdFont-Italic.ttf
# RecMonoLinear Nerd Font
# /usr/share/fonts/noto/NotoSansSinhalaUI-SemiCondensedThin.ttf
# Noto Sans Sinhala UI SemiCondensed
# /usr/share/fonts/noto/NotoSansHebrew-ExtraCondensedLight.ttf
# Noto Sans Hebrew
# /usr/share/fonts/noto/NotoSansOldNorthArabian-Regular.ttf
# Noto Sans Old North Arabian
# /usr/share/fonts/TTF/RecMonoDuotoneNerdFont-Regular.ttf
# RecMonoDuotone Nerd Font
# /usr/share/fonts/TTF/MesloLGSDZNerdFont-BoldItalic.ttf
# MesloLGSDZ Nerd Font
# /home/avanti/.local/share/fonts/latex/english/Serif/TimesBold.ttf
# Times
# /usr/share/fonts/TTF/FantasqueSansMNerdFontPropo-Regular.ttf
# FantasqueSansM Nerd Font Propo
# /home/avanti/.local/share/fonts/lxgw/LxgwBrightCode-v2.822/LXGWBrightCode-Light.ttf
# LXGW Bright Code
# /usr/share/fonts/noto/NotoSerifTamil-SemiCondensedExtraBold.ttf
# Noto Serif Tamil SemiCondensed
# /usr/share/fonts/TTF/IosevkaTermNerdFontMono-Regular.ttf
# IosevkaTerm NFM
# /usr/share/fonts/noto/NotoSansMyanmar-SemiCondensedLight.ttf
# Noto Sans Myanmar SemiCondensed
# /home/avanti/.local/share/fonts/latex/english/Serif/TimesNewRomanItalic.ttf
# Times New Roman
# /usr/share/fonts/noto/NotoSansCanadianAboriginal-SemiBold.ttf
# Noto Sans Canadian Aboriginal
# /usr/share/fonts/noto/NotoSerifSinhala-Black.ttf
# Noto Serif Sinhala
# /usr/share/fonts/TTF/3270NerdFontMono-SemiCondensed.ttf
# 3270 Nerd Font Mono
# /home/avanti/.local/share/fonts/mj/fonts/HTML-CSS/Asana-Math/otf/AsanaMathJax_Script-Regular.otf
# Asana Math
# /usr/share/fonts/TTF/SpaceMonoNerdFontPropo-Regular.ttf
# SpaceMono Nerd Font Propo
# /usr/share/fonts/noto/NotoSerifDevanagari-Thin.ttf
# Noto Serif Devanagari
# /usr/share/fonts/TTF/IosevkaTermNerdFont-Bold.ttf
# IosevkaTerm NF
# /usr/share/fonts/noto/NotoSansOgham-Regular.ttf
# Noto Sans Ogham
# /usr/share/fonts/noto/NotoSerif-ExtraCondensedLightItalic.ttf
# Noto Serif
# /usr/share/fonts/OTF/MonaspaceXenon-ExtraLight.otf
# Monaspace Xenon
# /usr/share/fonts/TTF/NotoSansMNerdFontPropo-Black.ttf
# NotoSansM NFP
# /usr/share/fonts/noto/NotoSansMalayalamUI-SemiBold.ttf
# Noto Sans Malayalam UI
# /usr/share/fonts/OTF/HurmitNerdFontMono-Light.otf
# Hurmit Nerd Font Mono
# /usr/share/fonts/noto/NotoSansThai-ExtraCondensedBold.ttf
# Noto Sans Thai
# /usr/share/fonts/TTF/AnonymiceProNerdFont-Bold.ttf
# AnonymicePro Nerd Font
# /usr/share/fonts/OTF/GeistMonoNerdFont-Light.otf
# GeistMono NF
# /home/avanti/.local/share/fonts/mj/fonts/HTML-CSS/Gyre-Termes/otf/GyreTermesMathJax_Normal-Regular.otf
# TeX Gyre Termes Math
# /usr/share/fonts/noto/NotoSerifArmenian-SemiCondensedMedium.ttf
# Noto Serif Armenian
# /usr/share/fonts/OTF/OverpassNerdFontPropo-Bold.otf
# Overpass Nerd Font Propo
# /usr/share/fonts/TTF/NotoSerifNerdFontPropo-CondensedBold.ttf
# NotoSerif NFP
# /usr/share/fonts/TTF/NotoSerifNerdFont-CondensedBoldItalic.ttf
# NotoSerif NF
# /usr/share/fonts/noto/NotoSerif-Light.ttf
# Noto Serif
# /usr/share/fonts/OTF/MonaspaceArgon-LightItalic.otf
# Monaspace Argon
# /usr/share/fonts/noto/NotoSansZanabazarSquare-Regular.ttf
# Noto Sans Zanabazar Square
# /usr/share/fonts/OTF/FandolBraille-Regular.otf
# Fandol Braille
# /usr/share/fonts/noto/NotoSansKannada-ExtraLight.ttf
# Noto Sans Kannada
# /usr/share/fonts/adobe-source-code-pro/SourceCodePro-Light.otf
# Source Code Pro
# /usr/share/fonts/noto/NotoSansAdlamUnjoined-Regular.ttf
# Noto Sans Adlam Unjoined
# /usr/share/fonts/TTF/VictorMonoNerdFontMono-Regular.ttf
# VictorMono NFM
# /usr/share/fonts/TTF/NotoSansNerdFont-Regular.ttf
# NotoSans NF
# /usr/share/fonts/TTF/NotoSansNerdFontPropo-SemiCondensedExtraBoldItalic.ttf
# NotoSans NFP
# /usr/share/fonts/noto/NotoSerifGeorgian-SemiCondensedSemiBold.ttf
# Noto Serif Georgian
# /usr/share/fonts/TTF/CaskaydiaMonoNerdFont-ExtraLight.ttf
# CaskaydiaMono NF
# /usr/share/fonts/noto/NotoSansGeorgian-CondensedLight.ttf
# Noto Sans Georgian
# /usr/share/fonts/OTF/MonaspiceRnNerdFont-Light.otf
# MonaspiceRn NF
# /usr/share/fonts/TTF/RecMonoSmCasualNerdFont-Regular.ttf
# RecMonoSmCasual Nerd Font
# /home/avanti/.local/share/fonts/lxgw/LxgwBrightCode-v2.822/LXGWBrightCode-ExtraLightItalic.ttf
# LXGW Bright Code
# /usr/share/fonts/noto/NotoSansSinhalaUI-SemiCondensedSemiBold.ttf
# Noto Sans Sinhala UI SemiCondensed
# /usr/share/fonts/noto/NotoSerifEthiopic-CondensedThin.ttf
# Noto Serif Ethiopic Condensed
# /home/avanti/.local/share/fonts/ysabeau/Ysabeau-LightItalic.otf
# Ysabeau
# /usr/share/fonts/TTF/VictorMonoNerdFontMono-LightOblique.ttf
# VictorMono NFM
# /usr/share/fonts/noto/NotoSerifTibetan-Thin.ttf
# Noto Serif Tibetan
# /home/avanti/.local/share/fonts/fangzheng/方正静蕾简体.TTF
# FZJingLeiS-R-GB
# /usr/share/fonts/TTF/NotoSansMNerdFont-CondensedBlack.ttf
# NotoSansM NF
# /usr/share/fonts/noto/NotoSerifSinhala-ExtraCondensed.ttf
# Noto Serif Sinhala ExtraCondensed
# /usr/share/fonts/noto/NotoSerifTamil-SemiCondensedLightItalic.ttf
# Noto Serif Tamil SemiCondensed
# /usr/share/fonts/TTF/GoMonoNerdFont-Italic.ttf
# GoMono Nerd Font
# /usr/share/fonts/TTF/BlexMonoNerdFont-ExtraLightItalic.ttf
# BlexMono Nerd Font
# /usr/share/fonts/TTF/InconsolataGoNerdFont-Bold.ttf
# InconsolataGo Nerd Font
# /usr/share/fonts/OTF/CodeNewRomanNerdFont-Bold.otf
# CodeNewRoman Nerd Font
# /usr/share/fonts/noto/NotoSerif-CondensedMediumItalic.ttf
# Noto Serif
# /usr/share/fonts/OTF/lmromandunh10-oblique.otf
# LMRomanDunh10
# /usr/share/fonts/wps-fonts/cour.ttf
# Courier New
# /usr/share/fonts/TTF/RecMonoDuotoneNerdFontPropo-Regular.ttf
# RecMonoDuotone Nerd Font Propo
# /usr/share/fonts/OTF/GeistMonoNerdFontMono-SemiBold.otf
# GeistMono NFM
# /usr/share/fonts/noto/NotoSerifHebrew-CondensedBold.ttf
# Noto Serif Hebrew
# /usr/share/fonts/noto/NotoSansTelugu-ExtraCondensedBlack.ttf
# Noto Sans Telugu
# /usr/share/fonts/noto/NotoSansDevanagariUI-ExtraCondensedExtraLight.ttf
# Noto Sans Devanagari UI ExtraCondensed
# /usr/share/fonts/wps-fonts/taile.ttf
# Microsoft Tai Le
# /home/avanti/.local/share/fonts/mj/fonts/HTML-CSS/Gyre-Pagella/otf/GyrePagellaMathJax_Variants-Regular.otf
# TeX Gyre Pagella Math
# /usr/share/fonts/wps-fonts/ariali.ttf
# Arial
# /usr/share/fonts/noto/NotoSansBassaVah-SemiBold.ttf
# Noto Sans Bassa Vah
# /usr/share/fonts/noto/NotoSansTamil-ExtraCondensed.ttf
# Noto Sans Tamil ExtraCondensed
# /usr/share/fonts/TTF/AgaveNerdFont-Bold.ttf
# Agave Nerd Font
# /home/avanti/.local/share/fonts/mj/fonts/HTML-CSS/Gyre-Termes/otf/GyreTermesMathJax_Latin-Regular.otf
# TeX Gyre Termes Math
# /usr/share/fonts/TTF/NotoSansNerdFont-CondensedBold.ttf
# NotoSans NF
# /usr/share/fonts/TTF/BlexMonoNerdFontPropo-Light.ttf
# BlexMono Nerd Font Propo
# /usr/share/fonts/OTF/MonaspiceNeNerdFont-Medium.otf
# MonaspiceNe NF
# /home/avanti/.local/share/fonts/lxgw/LxgwBrightCode-v2.822/LXGWBrightCode-LightItalic.ttf
# LXGW Bright Code
# /usr/share/fonts/OTF/MonaspaceNeon-SemiWideItalic.otf
# Monaspace Neon
# /usr/share/fonts/TTF/IosevkaTermSlabNerdFontMono-BoldOblique.ttf
# IosevkaTermSlab NFM
# /usr/share/fonts/wps-fonts/seguihis.ttf
# Segoe UI Historic
# /usr/share/fonts/noto/NotoSansEthiopic-Regular.ttf
# Noto Sans Ethiopic
# /usr/share/fonts/noto/NotoSerifLao-SemiCondensedBold.ttf
# Noto Serif Lao SemiCondensed
# /usr/share/fonts/TTF/NotoSansMNerdFontPropo-CondensedBlack.ttf
# NotoSansM NFP
# /usr/share/fonts/TTF/NotoSansNerdFontPropo-SemiCondensedBlack.ttf
# NotoSans NFP
# /usr/share/fonts/TTF/IosevkaNerdFontPropo-HeavyItalic.ttf
# Iosevka NFP
# /usr/share/fonts/OTF/MonaspaceArgon-SemiWideExtraLightItalic.otf
# Monaspace Argon
# /usr/share/fonts/noto/NotoSansArmenian-SemiCondensedThin.ttf
# Noto Sans Armenian
# /usr/share/fonts/TTF/NotoSansMNerdFontMono-CondensedExtraLight.ttf
# NotoSansM NFM
# /usr/share/fonts/noto/NotoSerifSinhala-SemiCondensedThin.ttf
# Noto Serif Sinhala SemiCondensed
# /usr/share/fonts/TTF/DejaVuSans-Oblique.ttf
# DejaVu Sans
# /usr/share/fonts/TTF/IosevkaTermNerdFontMono-Light.ttf
# IosevkaTerm NFM
# /usr/share/fonts/OTF/MonaspiceXeNerdFontPropo-Medium.otf
# MonaspiceXe NFP
# /usr/share/fonts/TTF/CaskaydiaMonoNerdFont-Italic.ttf
# CaskaydiaMono NF
# /usr/share/fonts/OTF/HurmitNerdFontPropo-Light.otf
# Hurmit Nerd Font Propo
# /usr/share/fonts/noto/NotoSansLao-ExtraCondensedMedium.ttf
# Noto Sans Lao ExtraCondensed
# /usr/share/fonts/noto/NotoSansArabic-ExtraCondensedExtraLight.ttf
# Noto Sans Arabic
# /home/avanti/.local/share/fonts/mj/fonts/HTML-CSS/STIX-Web/otf/STIXMathJax_Variants-Bold.otf
# STIX MathJax Variants
# /usr/share/fonts/noto/NotoSansDevanagari-CondensedThin.ttf
# Noto Sans Devanagari
# /usr/share/fonts/TTF/MesloLGLDZNerdFontPropo-Bold.ttf
# MesloLGLDZ Nerd Font Propo
# /usr/share/fonts/TTF/MesloLGLNerdFontPropo-Bold.ttf
# MesloLGL Nerd Font Propo
# /usr/share/fonts/noto/NotoSansMono-SemiCondensedExtraBold.ttf
# Noto Sans Mono
# /usr/share/fonts/adobe-source-code-pro/SourceCodePro-ExtraLightIt.otf
# Source Code Pro
# /usr/share/fonts/noto/NotoSansGurmukhi-ExtraBold.ttf
# Noto Sans Gurmukhi
# /usr/share/fonts/TTF/NotoSerifNerdFont-MediumItalic.ttf
# NotoSerif NF
# /usr/share/fonts/noto-cjk/NotoSerifCJK-SemiBold.ttc
# Noto Serif CJK JP
# /home/avanti/.local/share/fonts/ysabeau/YsabeauOffice-ExtraBlack.otf
# Ysabeau Office
# /usr/share/fonts/TTF/NotoSansNerdFont-CondensedRegular.ttf
# NotoSans NF
# /usr/share/fonts/noto/NotoSerifLao-CondensedLight.ttf
# Noto Serif Lao Condensed
# /usr/share/fonts/OTF/lmsans8-regular.otf
# LMSans8
# /usr/share/fonts/TTF/VictorMonoNerdFontMono-BoldOblique.ttf
# VictorMono NFM
# /usr/share/fonts/noto/NotoSansTelugu-ExtraCondensed.ttf
# Noto Sans Telugu
# /usr/share/fonts/noto/NotoSansKannada-CondensedExtraBold.ttf
# Noto Sans Kannada
# /usr/share/fonts/TTF/NotoSerifNerdFontPropo-ExtraCondensedBold.ttf
# NotoSerif NFP
# /usr/share/fonts/noto/NotoSansSinhalaUI-Regular.ttf
# Noto Sans Sinhala UI
# /home/avanti/.local/share/fonts/mj/dist/fonts/HTML-CSS/TeX/otf/MathJax_WinChrome-Regular.otf
# MathJax_WinChrome
# /usr/share/fonts/TTF/IosevkaTermNerdFont-ThinItalic.ttf
# IosevkaTerm NF
# /usr/share/fonts/noto/NotoSansMalayalamUI-Condensed.ttf
# Noto Sans Malayalam UI Condensed
# /usr/share/fonts/noto/NotoSansArmenian-Medium.ttf
# Noto Sans Armenian
# /usr/share/fonts/noto/NotoSansRejang-Regular.ttf
# Noto Sans Rejang
# /usr/share/fonts/noto/NotoSerifEthiopic-Thin.ttf
# Noto Serif Ethiopic
# /usr/share/fonts/TTF/ZedMonoNerdFontMono-BoldOblique.ttf
# ZedMono NFM
# /usr/share/fonts/TTF/NotoSerifNerdFont-Italic.ttf
# NotoSerif NF
# /home/avanti/.local/share/fonts/OperatorMonoLig2/OperatorMonoSSmLig-Medium.otf
# Operator Mono SSm Lig
# /usr/share/fonts/TTF/InconsolataNerdFontMono-Bold.ttf
# Inconsolata Nerd Font Mono
# /usr/share/fonts/noto/NotoSansMono-SemiCondensedSemiBold.ttf
# Noto Sans Mono
# /usr/share/fonts/TTF/IosevkaTermSlabNerdFont-LightItalic.ttf
# IosevkaTermSlab NF
# /usr/share/fonts/TTF/IosevkaTermSlabNerdFontMono-MediumOblique.ttf
# IosevkaTermSlab NFM
# /home/avanti/.local/share/fonts/ebgaramond/EBGaramond-Regular.ttf
# EB Garamond
# /usr/share/fonts/TTF/SauceCodeProNerdFont-BoldItalic.ttf
# SauceCodePro NF
# /usr/share/fonts/TTF/M+2NerdFont-Regular.ttf
# M+2 Nerd Font
# /usr/share/fonts/TTF/VictorMonoNerdFontMono-Italic.ttf
# VictorMono NFM
# /usr/share/fonts/TTF/MartianMonoNerdFontPropo-Regular.ttf
# MartianMono NFP
# /usr/share/fonts/noto/NotoSerifDisplay-CondensedLight.ttf
# Noto Serif Display Condensed
# /usr/share/fonts/TTF/SauceCodeProNerdFontMono-Black.ttf
# SauceCodePro NFM
# /usr/share/fonts/TTF/ZedMonoNerdFontPropo-LightItalic.ttf
# ZedMono NFP
# /usr/share/fonts/TTF/NotoSansMNerdFont-SemiCondensedMedium.ttf
# NotoSansM NF
# /usr/share/fonts/OTF/GeistMonoNerdFont-UltraBlack.otf
# GeistMono NF
# /usr/share/fonts/TTF/IosevkaNerdFont-ExtraBoldItalic.ttf
# Iosevka NF
# /usr/share/fonts/noto/NotoSerifArmenian-SemiCondensedSemiBold.ttf
# Noto Serif Armenian
# /usr/share/fonts/TTF/CaskaydiaCoveNerdFont-Light.ttf
# CaskaydiaCove NF
# /usr/share/fonts/noto/NotoSansSinhala-ExtraCondensedSemiBold.ttf
# Noto Sans Sinhala ExtraCondensed
# /usr/share/fonts/OTF/MonaspaceNeon-WideExtraBold.otf
# Monaspace Neon
# /usr/share/fonts/TTF/NotoSansNerdFontPropo-CondensedMedium.ttf
# NotoSans NFP
# /usr/share/fonts/noto/NotoSansTamilUI-Thin.ttf
# Noto Sans Tamil UI
# /usr/share/fonts/noto/NotoSerifGeorgian-SemiCondensedThin.ttf
# Noto Serif Georgian
# /usr/share/fonts/noto/NotoSansArabicUI-ExtraBold.ttf
# Noto Sans Arabic UI
# /usr/share/fonts/OTF/MonaspaceArgon-SemiWideSemiBold.otf
# Monaspace Argon
# /usr/share/fonts/noto/NotoSansTamilUI-CondensedMedium.ttf
# Noto Sans Tamil UI Condensed
# /usr/share/fonts/wps-office/HYZYB5.ttf
# HYZhongYuanB5
# /usr/share/fonts/noto/NotoSansGujaratiUI-SemiCondensedSemiBold.ttf
# Noto Sans Gujarati UI
# /usr/share/fonts/TTF/NotoSansMNerdFont-CondensedSemiBold.ttf
# NotoSansM NF
# /home/avanti/.local/share/fonts/latex/chinese/仿宋体/FangSong.ttf
# FangSong
# /usr/share/fonts/noto/NotoSansKayahLi-Regular.ttf
# Noto Sans Kayah Li
# /usr/share/fonts/noto/NotoSerifTamil-SemiCondensedThin.ttf
# Noto Serif Tamil SemiCondensed
# /usr/share/fonts/TTF/3270NerdFontMono-Regular.ttf
# 3270 Nerd Font Mono
# /usr/share/fonts/noto/NotoSansGurmukhiUI-ExtraCondensedBlack.ttf
# Noto Sans Gurmukhi UI ExtraCondensed
# /usr/share/fonts/noto/NotoSerif-CondensedMedium.ttf
# Noto Serif
# /usr/share/fonts/TTF/NotoSansNerdFont-CondensedSemiBoldItalic.ttf
# NotoSans NF
# /usr/share/fonts/OTF/MonaspiceXeNerdFont-Medium.otf
# MonaspiceXe NF
# /usr/share/fonts/noto/NotoSansTamilUI-SemiCondensedThin.ttf
# Noto Sans Tamil UI SemiCondensed
# /usr/share/fonts/TTF/IosevkaTermNerdFont-HeavyItalic.ttf
# IosevkaTerm NF
# /usr/share/fonts/TTF/ProFontIIxNerdFont-Regular.ttf
# ProFont IIx Nerd Font
# /home/avanti/.local/share/fonts/latex/chinese/仿宋体/STFangsong.ttf
# STFangsong
# /usr/share/fonts/noto/NotoSansKannadaUI-SemiCondensedBold.ttf
# Noto Sans Kannada UI
# /home/avanti/.local/share/fonts/fangzheng/方正隶变_GBK.TTF
# FZLiBian-S02
# /usr/share/fonts/noto/NotoSansTamilUI-ExtraCondensedLight.ttf
# Noto Sans Tamil UI ExtraCondensed
# /usr/share/fonts/TTF/LilexNerdFontPropo-Regular.ttf
# Lilex Nerd Font Propo
# /usr/share/fonts/noto/NotoSerifThai-Regular.ttf
# Noto Serif Thai
# /usr/share/fonts/TTF/NotoSansMNerdFontPropo-ExtraCondensedSemiBold.ttf
# NotoSansM NFP
# /usr/share/fonts/TTF/DaddyTimeMonoNerdFontMono-Regular.ttf
# DaddyTimeMono Nerd Font Mono
# /usr/share/fonts/TTF/ZedMonoNerdFont-MediumItalic.ttf
# ZedMono NF
# /usr/share/fonts/noto/NotoSansHanunoo-Regular.ttf
# Noto Sans Hanunoo
# /usr/share/fonts/noto/NotoSansArabic-SemiCondensedThin.ttf
# Noto Sans Arabic
# /usr/share/fonts/gsfonts/NimbusSans-Italic.otf
# Nimbus Sans
# /usr/share/fonts/noto/NotoSansDevanagariUI-ExtraCondensedBold.ttf
# Noto Sans Devanagari UI ExtraCondensed
# /usr/share/fonts/TTF/ProFontWindowsNerdFontPropo-Regular.ttf
# ProFontWindows Nerd Font Propo
# /usr/share/fonts/noto/NotoSansMono-ExtraCondensed.ttf
# Noto Sans Mono
# /usr/share/fonts/wps-fonts/arial.ttf
# Arial
# /usr/share/fonts/noto/NotoSerifBengali-CondensedBold.ttf
# Noto Serif Bengali
# /usr/share/fonts/TTF/IosevkaNerdFontMono-Light.ttf
# Iosevka NFM
# /usr/share/fonts/TTF/RobotoMonoNerdFont-Medium.ttf
# RobotoMono Nerd Font
# /usr/share/fonts/TTF/AnonymiceProNerdFontMono-Regular.ttf
# AnonymicePro Nerd Font Mono
# /usr/share/fonts/TTF/IosevkaNerdFontPropo-BoldOblique.ttf
# Iosevka NFP
# /usr/share/fonts/noto/NotoSerifDevanagari-SemiCondensedSemiBold.ttf
# Noto Serif Devanagari
# /usr/share/fonts/noto/NotoSansMalayalamUI-CondensedBold.ttf
# Noto Sans Malayalam UI Condensed
# /usr/share/fonts/TTF/MartianMonoNerdFont-CondensedMedium.ttf
# MartianMono NF
# /usr/share/fonts/noto/NotoSans-ExtraCondensedThin.ttf
# Noto Sans
# /usr/share/fonts/TTF/CaskaydiaMonoNerdFontPropo-Light.ttf
# CaskaydiaMono NFP
# /usr/share/fonts/noto/NotoSansMalayalamUI-ExtraCondensedBold.ttf
# Noto Sans Malayalam UI ExtraCondensed
# /usr/share/fonts/noto/NotoSansThaiLooped-CondensedBold.ttf
# Noto Sans Thai Looped Condensed
# /usr/share/fonts/TTF/IosevkaNerdFontPropo-BoldItalic.ttf
# Iosevka NFP
# /usr/share/fonts/OTF/lmmonolt10-oblique.otf
# LMMonoLt10
# /usr/share/fonts/TTF/BlexMonoNerdFont-Thin.ttf
# BlexMono Nerd Font
# /usr/share/fonts/wps-fonts/consolai.ttf
# Consolas
# /usr/share/fonts/TTF/VictorMonoNerdFont-MediumOblique.ttf
# VictorMono NF
# /usr/share/fonts/noto/NotoSansMalayalamUI-SemiCondensedBlack.ttf
# Noto Sans Malayalam UI SemiCondensed
# /usr/share/fonts/adobe-source-code-pro/SourceCodePro-It.otf
# Source Code Pro
# /usr/share/fonts/OTF/MonaspaceArgon-SemiBoldItalic.otf
# Monaspace Argon
# /usr/share/fonts/wps-fonts/palai.ttf
# Palatino Linotype
# /home/avanti/.local/share/fonts/puhuiti3/AlibabaPuHuiTi-3-75-SemiBold/AlibabaPuHuiTi-3-75-SemiBold.ttf
# Alibaba PuHuiTi 3.0
# /usr/share/fonts/TTF/RobotoMonoNerdFontMono-Bold.ttf
# RobotoMono Nerd Font Mono
# /usr/share/fonts/TTF/LilexNerdFont-Bold.ttf
# Lilex Nerd Font
# /usr/share/fonts/TTF/NotoSerifNerdFontPropo-ExtraCondensedLight.ttf
# NotoSerif NFP
# /usr/share/fonts/noto/NotoSansSaurashtra-Regular.ttf
# Noto Sans Saurashtra
# /usr/share/fonts/TTF/iMWritingMonoNerdFontMono-Bold.ttf
# iMWritingMono Nerd Font Mono
# /usr/share/fonts/TTF/JetBrainsMonoNLNerdFont-SemiBold.ttf
# JetBrainsMonoNL NF
# /usr/share/fonts/noto/NotoSansHebrew-Black.ttf
# Noto Sans Hebrew
# /usr/share/fonts/noto/NotoSansMalayalamUI-ExtraCondensedBlack.ttf
# Noto Sans Malayalam UI ExtraCondensed
# /usr/share/fonts/TTF/CousineNerdFontPropo-Regular.ttf
# Cousine Nerd Font Propo
# /usr/share/fonts/OTF/lmromancaps10-regular.otf
# LMRomanCaps10
# /usr/share/fonts/noto/NotoSerif-ExtraCondensedExtraBoldItalic.ttf
# Noto Serif
# /usr/share/fonts/noto/NotoSansTelugu-CondensedExtraBold.ttf
# Noto Sans Telugu
# /usr/share/fonts/TTF/BlexMonoNerdFont-TextItalic.ttf
# BlexMono Nerd Font
# /home/avanti/.local/share/fonts/mj/dist/fonts/HTML-CSS/STIX-Web/otf/STIXMathJax_SansSerif-Italic.otf
# STIX MathJax SansSerif
# /usr/share/fonts/noto/NotoSansArmenian-CondensedLight.ttf
# Noto Sans Armenian
# /usr/share/fonts/TTF/D2CodingLigatureNerdFontMono-Regular.ttf
# D2CodingLigature Nerd Font Mono
# /usr/share/fonts/noto/NotoSansBengali-SemiCondensedBlack.ttf
# Noto Sans Bengali
# /usr/share/fonts/noto/NotoSansSinhala-ExtraCondensed.ttf
# Noto Sans Sinhala ExtraCondensed
# /usr/share/fonts/TTF/RecMonoSmCasualNerdFont-Italic.ttf
# RecMonoSmCasual Nerd Font
# /usr/share/fonts/TTF/ZedMonoNerdFont-ExtendedExtraBoldOblique.ttf
# ZedMono NF
# /home/avanti/.local/share/fonts/latex/chinese/宋体/AdobeSongStd.otf
# Adobe Song Std
# /usr/share/fonts/TTF/VictorMonoNerdFontMono-ThinOblique.ttf
# VictorMono NFM
# /home/avanti/.local/share/fonts/ysabeau/YsabeauInfant-MediumItalic.otf
# Ysabeau Infant
# /usr/share/fonts/TTF/ProggyCleanSZNerdFont-Regular.ttf
# ProggyCleanSZ Nerd Font
# /home/avanti/.local/share/fonts/fangzheng/方正兰亭粗黑_GBK.ttf
# FZLanTingHei-B-GBK
# /usr/share/fonts/OTF/GeistMonoNerdFontPropo-Medium.otf
# GeistMono NFP
# /usr/share/fonts/TTF/JetBrainsMonoNerdFont-BoldItalic.ttf
# JetBrainsMono NF
# /home/avanti/.local/share/fonts/latex/chinese/黑体/WenQuanYiZenHei.ttc
# WenQuanYi Zen Hei
# /usr/share/fonts/TTF/SpaceMonoNerdFontPropo-BoldItalic.ttf
# SpaceMono Nerd Font Propo
# /usr/share/fonts/noto/NotoSerifKhmer-CondensedExtraBold.ttf
# Noto Serif Khmer
# /usr/share/fonts/noto/NotoSansDevanagari-Light.ttf
# Noto Sans Devanagari
# /usr/share/fonts/noto/NotoSansDevanagariUI-Medium.ttf
# Noto Sans Devanagari UI
# /usr/share/fonts/noto/NotoSansGujaratiUI-CondensedLight.ttf
# Noto Sans Gujarati UI
# /home/avanti/.local/share/fonts/mj/fonts/HTML-CSS/Latin-Modern/otf/LatinModernMathJax_Shapes-Regular.otf
# Latin Modern Math
# /usr/share/fonts/TTF/CaskaydiaCoveNerdFont-SemiLight.ttf
# CaskaydiaCove NF
# /usr/share/fonts/TTF/IosevkaNerdFontPropo-ExtraBold.ttf
# Iosevka NFP
# /usr/share/fonts/TTF/M+CodeLat50NerdFontMono-Bold.ttf
# M+CodeLat50 Nerd Font Mono
# /usr/share/fonts/TTF/FantasqueSansMNerdFontMono-Regular.ttf
# FantasqueSansM Nerd Font Mono
# /usr/share/fonts/TTF/CaskaydiaCoveNerdFontPropo-SemiLight.ttf
# CaskaydiaCove NFP
# /usr/share/fonts/TTF/IosevkaTermSlabNerdFontPropo-MediumOblique.ttf
# IosevkaTermSlab NFP
# /usr/share/fonts/noto/NotoSerifMyanmar-ExtraCondensedSemiBold.ttf
# Noto Serif Myanmar ExtraCondensed
# /usr/share/fonts/TTF/MesloLGSDZNerdFontPropo-BoldItalic.ttf
# MesloLGSDZ Nerd Font Propo
# /usr/share/fonts/OTF/lmroman8-regular.otf
# LMRoman8
# /usr/share/fonts/noto/NotoSerifDevanagari-CondensedSemiBold.ttf
# Noto Serif Devanagari
# /usr/share/fonts/TTF/ZedMonoNerdFontMono-ExtendedExtraBoldItalic.ttf
# ZedMono NFM
# /usr/share/fonts/TTF/ZedMonoNerdFontPropo-Medium.ttf
# ZedMono NFP
# /usr/share/fonts/noto/NotoSansArabicUI-ExtraCondensedExtraLight.ttf
# Noto Sans Arabic UI
# /usr/share/fonts/noto/NotoSansGeorgian-ExtraCondensedExtraBold.ttf
# Noto Sans Georgian
# /usr/share/fonts/noto/NotoSerifKhmer-ExtraCondensedSemiBold.ttf
# Noto Serif Khmer
# /usr/share/fonts/noto/NotoSerif-Regular.ttf
# Noto Serif
# /usr/share/fonts/noto/NotoNaskhArabic-Medium.ttf
# Noto Naskh Arabic
# /usr/share/fonts/noto/NotoSerifGeorgian-ExtraCondensedThin.ttf
# Noto Serif Georgian
# /usr/share/fonts/noto/NotoSansGujarati-CondensedSemiBold.ttf
# Noto Sans Gujarati
# /usr/share/fonts/OTF/MonaspaceKrypton-WideRegular.otf
# Monaspace Krypton
# /home/avanti/.local/share/fonts/mj/fonts/HTML-CSS/Neo-Euler/otf/NeoEulerMathJax_Normal-Regular.otf
# Neo Euler
# /usr/share/fonts/noto/NotoSansMalayalam-Light.ttf
# Noto Sans Malayalam
# /usr/share/fonts/TTF/FiraCodeNerdFontPropo-Regular.ttf
# FiraCode Nerd Font Propo
# /usr/share/fonts/TTF/JetBrainsMonoNerdFontPropo-BoldItalic.ttf
# JetBrainsMono NFP
# /usr/share/fonts/noto/NotoSerifDevanagari-CondensedExtraLight.ttf
# Noto Serif Devanagari
# /home/avanti/.local/share/fonts/feihong/A-OTF-KYOKAICAPRO-MEDIUM.OTF
# A-OTF Kyoukasho ICA Pro
# /usr/share/fonts/TTF/BitstromWeraNerdFontPropo-Regular.ttf
# BitstromWera Nerd Font Propo
# /home/avanti/.local/share/fonts/mj/dist/fonts/HTML-CSS/TeX/otf/MathJax_SansSerif-Bold.otf
# MathJax_SansSerif
# /usr/share/fonts/noto/NotoSans-CondensedLight.ttf
# Noto Sans
# /usr/share/fonts/TTF/IosevkaTermSlabNerdFontPropo-Bold.ttf
# IosevkaTermSlab NFP
# /usr/share/fonts/TTF/MesloLGLNerdFontPropo-Regular.ttf
# MesloLGL Nerd Font Propo
# /usr/share/fonts/noto/NotoSansArabic-ExtraCondensed.ttf
# Noto Sans Arabic
# /usr/share/fonts/noto/NotoSerifSinhala-CondensedMedium.ttf
# Noto Serif Sinhala Condensed
# /home/avanti/.local/share/fonts/ysabeau/YsabeauSC-ExtraBold.otf
# Ysabeau SC
# /usr/share/fonts/noto/NotoSansKannada-SemiCondensed.ttf
# Noto Sans Kannada
# /usr/share/fonts/noto/NotoSerifDisplay-SemiCondensedThinItalic.ttf
# Noto Serif Display SemiCondensed
# /usr/share/fonts/noto/NotoSansKannadaUI-ExtraCondensedSemiBold.ttf
# Noto Sans Kannada UI
# /usr/share/fonts/TTF/IosevkaTermSlabNerdFontPropo-Medium.ttf
# IosevkaTermSlab NFP
# /usr/share/fonts/noto/NotoSansBassaVah-Bold.ttf
# Noto Sans Bassa Vah
# /usr/share/fonts/noto/NotoSansCherokee-Black.ttf
# Noto Sans Cherokee
# /usr/share/fonts/noto/NotoKufiArabic-Medium.ttf
# Noto Kufi Arabic
# /usr/share/fonts/TTF/iMWritingDuoNerdFontPropo-Bold.ttf
# iMWritingDuo Nerd Font Propo
# /usr/share/fonts/noto/NotoSerifMyanmar-CondensedMedium.ttf
# Noto Serif Myanmar Condensed
# /usr/share/fonts/OTF/MonaspaceRadon-SemiWideSemiBoldItalic.otf
# Monaspace Radon
# /usr/share/fonts/noto/NotoSansTamil-SemiCondensedBold.ttf
# Noto Sans Tamil SemiCondensed
# /usr/share/fonts/noto/NotoSerifDisplay-CondensedItalic.ttf
# Noto Serif Display Condensed
# /usr/share/fonts/noto/NotoSansSinhala-SemiCondensed.ttf
# Noto Sans Sinhala SemiCondensed
# /usr/share/fonts/TTF/M+1NerdFont-Black.ttf
# M+1 Nerd Font
# /usr/share/fonts/TTF/CaskaydiaCoveNerdFont-LightItalic.ttf
# CaskaydiaCove NF
# /usr/share/fonts/noto/NotoSerifSinhala-Bold.ttf
# Noto Serif Sinhala
# /usr/share/fonts/noto/NotoSansArabicUI-CondensedMedium.ttf
# Noto Sans Arabic UI
# /usr/share/fonts/TTF/VictorMonoNerdFontPropo-LightOblique.ttf
# VictorMono NFP
# /usr/share/fonts/TTF/LektonNerdFontPropo-Regular.ttf
# Lekton Nerd Font Propo
# /usr/share/fonts/TTF/iMWritingMonoNerdFont-Italic.ttf
# iMWritingMono Nerd Font
# /usr/share/fonts/adobe-source-code-pro/SourceCodePro-LightIt.otf
# Source Code Pro
# /usr/share/fonts/noto/NotoSerifDevanagari-SemiCondensedBold.ttf
# Noto Serif Devanagari
# /usr/share/fonts/noto/NotoSansDuployan-Regular.ttf
# Noto Sans Duployan
# /usr/share/fonts/noto/NotoSerifDevanagari-CondensedExtraBold.ttf
# Noto Serif Devanagari
# /usr/share/fonts/TTF/DejaVuMathTeXGyre.ttf
# DejaVu Math TeX Gyre
# /home/avanti/.local/share/fonts/latex/chinese/黑体/STHeiti.ttf
# STHeiti
# /usr/share/fonts/OTF/MonaspaceArgon-ExtraBoldItalic.otf
# Monaspace Argon
# /usr/share/fonts/noto/NotoSansTakri-Regular.ttf
# Noto Sans Takri
# /home/avanti/.local/share/fonts/mj/dist/fonts/HTML-CSS/STIX-Web/otf/STIXMathJax_Shapes-BoldItalic.otf
# STIX MathJax Shapes
# /usr/share/fonts/noto/NotoSerifMyanmar-Black.ttf
# Noto Serif Myanmar
# /usr/share/fonts/noto/NotoSansEthiopic-ExtraCondensedExtraLight.ttf
# Noto Sans Ethiopic ExtraCondensed
# /home/avanti/.local/share/fonts/ysabeau/YsabeauOffice-ExtraThin.otf
# Ysabeau Office
# /home/avanti/.local/share/fonts/fangzheng/方正粗金陵简繁.ttf
# FZJinL-B-GB
# /usr/share/fonts/noto/NotoSansGurmukhi-ExtraCondensedBold.ttf
# Noto Sans Gurmukhi ExtraCondensed
# /usr/share/fonts/TTF/NotoSerifNerdFont-SemiCondensedBold.ttf
# NotoSerif NF
# /usr/share/fonts/TTF/JetBrainsMonoNerdFontPropo-LightItalic.ttf
# JetBrainsMono NFP
# /home/avanti/.local/share/fonts/mj/fonts/HTML-CSS/Asana-Math/otf/AsanaMathJax_Size2-Regular.otf
# Asana Math
# /usr/share/fonts/noto/NotoSerifSinhala-SemiCondensedSemiBold.ttf
# Noto Serif Sinhala SemiCondensed
# /usr/share/fonts/TTF/IosevkaTermNerdFontMono-ExtraLight.ttf
# IosevkaTerm NFM
# /usr/share/fonts/noto/NotoSansGurmukhi-CondensedSemiBold.ttf
# Noto Sans Gurmukhi Condensed
# /usr/share/fonts/TTF/NotoSerifNerdFont-SemiCondensedExtraBold.ttf
# NotoSerif NF
# /usr/share/fonts/TTF/NotoSansNerdFontPropo-SemiCondensedSemiBoldItalic.ttf
# NotoSans NFP
# /usr/share/fonts/noto/NotoSansTamil-Regular.ttf
# Noto Sans Tamil
# /usr/share/fonts/gsfonts/URWGothic-DemiOblique.otf
# URW Gothic
# /usr/share/fonts/OTF/MonaspaceXenon-SemiWideLight.otf
# Monaspace Xenon
# /usr/share/fonts/TTF/IosevkaTermNerdFontPropo-BoldOblique.ttf
# IosevkaTerm NFP
# /usr/share/fonts/TTF/JetBrainsMonoNerdFontMono-SemiBoldItalic.ttf
# JetBrainsMono NFM
# /usr/share/fonts/TTF/MesloLGSDZNerdFont-Italic.ttf
# MesloLGSDZ Nerd Font
# /usr/share/fonts/noto/NotoSerifToto-Regular.ttf
# Noto Serif Toto
# /usr/share/fonts/OTF/HurmitNerdFont-Bold.otf
# Hurmit Nerd Font
# /home/avanti/.local/share/fonts/lxgw/LxgwBrightCode-v2.822/LXGWBrightCode-Italic.ttf
# LXGW Bright Code
# /usr/share/fonts/TTF/NotoSansNerdFontPropo-ExtraCondensedExtraBold.ttf
# NotoSans NFP
# /usr/share/fonts/noto/NotoSerifMyanmar-SemiCondensedExtraLight.ttf
# Noto Serif Myanmar SemiCondensed
# /usr/share/fonts/noto/NotoSansSinhala-SemiBold.ttf
# Noto Sans Sinhala
# /usr/share/fonts/noto/NotoSerifGeorgian-SemiCondensedExtraBold.ttf
# Noto Serif Georgian
# /usr/share/fonts/noto/NotoSansLimbu-Regular.ttf
# Noto Sans Limbu
# /usr/share/fonts/noto/NotoSerifDisplay-SemiCondensedBlack.ttf
# Noto Serif Display SemiCondensed
# /usr/share/fonts/noto/NotoSansBengaliUI-ExtraCondensed.ttf
# Noto Sans Bengali UI ExtraCondensed
# /usr/share/fonts/noto/NotoSansTeluguUI-Black.ttf
# Noto Sans Telugu UI
# /home/avanti/.local/share/fonts/mj/fonts/HTML-CSS/STIX-Web/otf/STIXMathJax_Fraktur-Bold.otf
# STIX MathJax Fraktur
# /usr/share/fonts/TTF/IosevkaTermSlabNerdFontPropo-ExtraBold.ttf
# IosevkaTermSlab NFP
# /usr/share/fonts/TTF/LiterationMonoNerdFontMono-Regular.ttf
# LiterationMono Nerd Font Mono
# /usr/share/fonts/TTF/NotoSansNerdFont-ExtraCondensedSemiBoldItalic.ttf
# NotoSans NF
# /usr/share/fonts/noto/NotoSansEthiopic-Condensed.ttf
# Noto Sans Ethiopic Condensed
# /usr/share/fonts/wps-fonts/calibril.ttf
# Calibri
# /usr/share/fonts/TTF/NotoSansMNerdFont-ExtraCondensedSemiBold.ttf
# NotoSansM NF
# /usr/share/fonts/noto/NotoSerifTamil-ExtraCondensedExtraBold.ttf
# Noto Serif Tamil ExtraCondensed
# /usr/share/fonts/TTF/NotoSansMNerdFontPropo-CondensedLight.ttf
# NotoSansM NFP
# /usr/share/fonts/OTF/OverpassMNerdFont-Bold.otf
# OverpassM Nerd Font
# /home/avanti/.local/share/fonts/mj/fonts/HTML-CSS/Neo-Euler/otf/NeoEulerMathJax_Variants-Regular.otf
# Neo Euler
# /usr/share/fonts/noto/NotoSansTeluguUI-ExtraCondensedLight.ttf
# Noto Sans Telugu UI
# /usr/share/fonts/TTF/NotoSerifNerdFontPropo-SemiCondensedExtraBoldItalic.ttf
# NotoSerif NFP
# /usr/share/fonts/noto/NotoSerifKhmer-Regular.ttf
# Noto Serif Khmer
# /usr/share/fonts/noto/NotoSansMiao-Regular.ttf
# Noto Sans Miao
# /usr/share/fonts/TTF/M+CodeLat50NerdFontPropo-Regular.ttf
# M+CodeLat50 Nerd Font Propo
# /usr/share/fonts/TTF/NotoSansMNerdFont-ExtraCondensedThin.ttf
# NotoSansM NF
# /usr/share/fonts/TTF/IosevkaNerdFontPropo-Bold.ttf
# Iosevka NFP
# /usr/share/fonts/noto/NotoSansThai-ExtraCondensedExtraBold.ttf
# Noto Sans Thai
# /home/avanti/.local/share/fonts/OperatorMonoLig2/OperatorMonoSSmLig-Bold.otf
# Operator Mono SSm Lig
# /usr/share/fonts/noto/NotoSansSymbols-Medium.ttf
# Noto Sans Symbols
# /usr/share/fonts/noto/NotoSansGeorgian-CondensedBold.ttf
# Noto Sans Georgian
# /usr/share/fonts/TTF/M+CodeLat50NerdFontMono-SemiBold.ttf
# M+CodeLat50 Nerd Font Mono
# /usr/share/fonts/noto/NotoSansKhmer-Condensed.ttf
# Noto Sans Khmer
# /home/avanti/.local/share/fonts/fangzheng/方正铁筋隶书_GBK.ttf
# FZTieJinLiShu-S17
# /usr/share/fonts/noto/NotoSansYi-Regular.ttf
# Noto Sans Yi
# /usr/share/fonts/TTF/M+CodeLat50NerdFontMono-ExtraLight.ttf
# M+CodeLat50 Nerd Font Mono
# /home/avanti/.local/share/fonts/fangzheng/方正少儿_GBK.ttf
# FZShaoEr-M11
# /usr/share/fonts/TTF/IosevkaNerdFontMono-ExtraLight.ttf
# Iosevka NFM
# /usr/share/fonts/TTF/NotoSansNerdFont-ExtraCondensedExtraBold.ttf
# NotoSans NF
# /usr/share/fonts/TTF/FantasqueSansMNerdFontMono-Italic.ttf
# FantasqueSansM Nerd Font Mono
# /usr/share/fonts/noto/NotoSansGujarati-SemiCondensed.ttf
# Noto Sans Gujarati
# /usr/share/fonts/noto/NotoSansHebrew-CondensedThin.ttf
# Noto Sans Hebrew
# /usr/share/fonts/TTF/IosevkaTermNerdFontMono-HeavyItalic.ttf
# IosevkaTerm NFM
# /usr/share/fonts/noto/NotoSansArmenian-ExtraCondensedBold.ttf
# Noto Sans Armenian
# /usr/share/fonts/TTF/NotoSerifNerdFont-ExtraCondensedBlack.ttf
# NotoSerif NF
# /usr/share/fonts/TTF/NotoSerifNerdFontPropo-ExtraCondensedBlack.ttf
# NotoSerif NFP
# /usr/share/fonts/OTF/MonaspaceNeon-ExtraBoldItalic.otf
# Monaspace Neon
# /usr/share/fonts/TTF/DejaVuSansMNerdFont-Oblique.ttf
# DejaVuSansM Nerd Font
# /usr/share/fonts/noto/NotoSansGujaratiUI-ExtraCondensedBold.ttf
# Noto Sans Gujarati UI
# /usr/share/fonts/noto/NotoSerifLao-SemiCondensedExtraBold.ttf
# Noto Serif Lao SemiCondensed
# /usr/share/fonts/wps-fonts/ebrima.ttf
# Ebrima
# /usr/share/fonts/TTF/LilexNerdFont-Thin.ttf
# Lilex Nerd Font
# /usr/share/fonts/noto/NotoSerifVithkuqi-Medium.ttf
# Noto Serif Vithkuqi
# /home/avanti/.local/share/fonts/fangzheng/方正兰亭中黑_GBK.ttf
# FZLanTingHei-DB-GBK
# /home/avanti/.local/share/fonts/mj/fonts/HTML-CSS/Asana-Math/otf/AsanaMathJax_SansSerif-Regular.otf
# Asana Math
# /usr/share/fonts/noto/NotoSansBengali-CondensedThin.ttf
# Noto Sans Bengali
# /usr/share/fonts/TTF/FiraCodeNerdFontMono-Medium.ttf
# FiraCode Nerd Font Mono
# /usr/share/fonts/OTF/MonaspaceRadon-LightItalic.otf
# Monaspace Radon
# /usr/share/fonts/noto/NotoSansMyanmar-CondensedExtraLight.ttf
# Noto Sans Myanmar Condensed
# /usr/share/fonts/TTF/SauceCodeProNerdFontPropo-Black.ttf
# SauceCodePro NFP
# /usr/share/fonts/OTF/MonaspaceKrypton-Bold.otf
# Monaspace Krypton
# /usr/share/fonts/TTF/IosevkaTermNerdFont-ExtraBold.ttf
# IosevkaTerm NF
# /home/avanti/.local/share/fonts/mj/fonts/HTML-CSS/Gyre-Pagella/otf/GyrePagellaMathJax_Normal-Regular.otf
# TeX Gyre Pagella Math
# /usr/share/fonts/TTF/VictorMonoNerdFontPropo-Thin.ttf
# VictorMono NFP
# /usr/share/fonts/TTF/IosevkaTermSlabNerdFont-BoldItalic.ttf
# IosevkaTermSlab NF
# /usr/share/fonts/TTF/ZedMonoNerdFont-Oblique.ttf
# ZedMono NF
# /usr/share/fonts/TTF/TinosNerdFontPropo-Regular.ttf
# Tinos Nerd Font Propo
# /usr/share/fonts/noto/NotoSerifEthiopic-Medium.ttf
# Noto Serif Ethiopic
# /usr/share/fonts/wps-fonts/tahomabd.ttf
# Tahoma
# /usr/share/fonts/noto/NotoSansMalayalam-CondensedBold.ttf
# Noto Sans Malayalam Condensed
# /usr/share/fonts/TTF/CaskaydiaMonoNerdFontPropo-SemiLightItalic.ttf
# CaskaydiaMono NFP
# /usr/share/fonts/TTF/IosevkaNerdFontMono-ExtraBoldItalic.ttf
# Iosevka NFM
# /usr/share/fonts/noto/NotoSerifDisplay-ExtraCondensedBlack.ttf
# Noto Serif Display ExtraCondensed
# /usr/share/fonts/TTF/NotoSerifNerdFont-SemiCondensedSemiBoldItalic.ttf
# NotoSerif NF
# /home/avanti/.local/share/fonts/fangzheng/方正新报宋_GBK.ttf
# FZNew BaoSong-Z12
# /usr/share/fonts/noto/NotoSans-CondensedThinItalic.ttf
# Noto Sans
# /usr/share/fonts/noto/NotoSerifHebrew-ExtraCondensedExtraLight.ttf
# Noto Serif Hebrew
# /usr/share/fonts/noto/NotoSansMalayalam-CondensedExtraLight.ttf
# Noto Sans Malayalam Condensed
# /home/avanti/.local/share/fonts/mj/fonts/HTML-CSS/STIX-Web/otf/STIXMathJax_Latin-Bold.otf
# STIX MathJax Latin
# /usr/share/fonts/noto/NotoSansSinhalaUI-CondensedExtraLight.ttf
# Noto Sans Sinhala UI Condensed
# /usr/share/fonts/noto/NotoSans-SemiCondensedBoldItalic.ttf
# Noto Sans
# /usr/share/fonts/noto/NotoSerifHebrew-ExtraBold.ttf
# Noto Serif Hebrew
# /usr/share/fonts/OTF/HurmitNerdFontMono-LightItalic.otf
# Hurmit Nerd Font Mono
# /usr/share/fonts/noto/NotoSerifKhmer-SemiBold.ttf
# Noto Serif Khmer
# /usr/share/fonts/OTF/MonaspaceNeon-WideExtraBoldItalic.otf
# Monaspace Neon
# /usr/share/fonts/TTF/LilexNerdFont-Medium.ttf
# Lilex Nerd Font
# /usr/share/fonts/TTF/MesloLGSNerdFontPropo-Bold.ttf
# MesloLGS Nerd Font Propo
# /usr/share/fonts/OTF/lmmono10-regular.otf
# LMMono10
# /home/avanti/.local/share/fonts/mj/fonts/HTML-CSS/STIX-Web/otf/STIXMathJax_DoubleStruck-BoldItalic.otf
# STIX MathJax DoubleStruck
# /usr/share/fonts/noto/NotoSans-SemiCondensedBlack.ttf
# Noto Sans
# /usr/share/fonts/TTF/JetBrainsMonoNerdFont-SemiBold.ttf
# JetBrainsMono NF
# /usr/share/fonts/TTF/MesloLGLDZNerdFontMono-Bold.ttf
# MesloLGLDZ Nerd Font Mono
# /usr/share/fonts/TTF/ArimoNerdFontPropo-Regular.ttf
# Arimo Nerd Font Propo
# /usr/share/fonts/TTF/TerminessNerdFontPropo-Italic.ttf
# Terminess Nerd Font Propo
# /usr/share/fonts/OTF/MonaspaceRadon-SemiWideMedium.otf
# Monaspace Radon
# /usr/share/fonts/noto/NotoSansTaiViet-Regular.ttf
# Noto Sans Tai Viet
# /usr/share/fonts/TTF/GohuFont14NerdFontPropo-Regular.ttf
# GohuFont 14 Nerd Font Propo
# /home/avanti/.local/share/fonts/mj/dist/fonts/HTML-CSS/TeX/otf/MathJax_WinIE6-Regular.otf
# MathJax_WinIE6
# /usr/share/fonts/noto/NotoSansKannada-SemiCondensedMedium.ttf
# Noto Sans Kannada
# /usr/share/fonts/TTF/ZedMonoNerdFontPropo-ExtendedItalic.ttf
# ZedMono NFP
# /usr/share/fonts/noto/NotoSansKannada-Black.ttf
# Noto Sans Kannada
# /usr/share/fonts/TTF/0xProtoNerdFont-Regular.ttf
# 0xProto Nerd Font
# /usr/share/fonts/noto/NotoSerifDisplay-ExtraCondensedMediumItalic.ttf
# Noto Serif Display ExtraCondensed
# /usr/share/fonts/noto/NotoSerifMalayalam-Thin.ttf
# Noto Serif Malayalam
# /usr/share/fonts/TTF/NotoSansMNerdFont-ExtraCondensedExtraLight.ttf
# NotoSansM NF
# /usr/share/fonts/noto/NotoSans-SemiCondensedMedium.ttf
# Noto Sans
# /usr/share/fonts/noto/NotoSansTeluguUI-Condensed.ttf
# Noto Sans Telugu UI
# /usr/share/fonts/TTF/MonoidNerdFont-Regular.ttf
# Monoid Nerd Font
# /usr/share/fonts/TTF/IosevkaTermNerdFont-Italic.ttf
# IosevkaTerm NF
# /usr/share/fonts/TTF/CaskaydiaMonoNerdFontMono-SemiBold.ttf
# CaskaydiaMono NFM
# /usr/share/fonts/noto/NotoSansSyriacEastern-Thin.ttf
# Noto Sans Syriac Eastern
# /usr/share/fonts/noto/NotoSansGurmukhi-Thin.ttf
# Noto Sans Gurmukhi
# /usr/share/fonts/gnu-free/FreeMonoBoldOblique.otf
# FreeMono
# /usr/share/fonts/TTF/ZedMonoNerdFontMono-BoldItalic.ttf
# ZedMono NFM
# /usr/share/fonts/noto/NotoSansMeeteiMayek-Light.ttf
# Noto Sans Meetei Mayek
# /usr/share/fonts/noto/NotoSansArmenian-ExtraCondensedLight.ttf
# Noto Sans Armenian
# /usr/share/fonts/gnu-free/FreeSerifBoldItalic.otf
# FreeSerif
# /usr/share/fonts/OTF/MonaspaceNeon-SemiWideBoldItalic.otf
# Monaspace Neon
# /usr/share/fonts/TTF/IosevkaTermSlabNerdFont-ExtraBold.ttf
# IosevkaTermSlab NF
# /usr/share/fonts/TTF/JetBrainsMonoNerdFont-SemiBoldItalic.ttf
# JetBrainsMono NF
# /usr/share/fonts/TTF/NotoSansNerdFont-ExtraLightItalic.ttf
# NotoSans NF
# /usr/share/fonts/noto/NotoSerifSinhala-CondensedSemiBold.ttf
# Noto Serif Sinhala Condensed
# /usr/share/fonts/OTF/MonaspiceArNerdFontPropo-Italic.otf
# MonaspiceAr NFP
# /usr/share/fonts/noto/NotoSansKhmer-ExtraCondensedExtraBold.ttf
# Noto Sans Khmer
# /home/avanti/.local/share/fonts/ysabeau/YsabeauSC-Bold.otf
# Ysabeau SC
# /usr/share/fonts/TTF/MartianMonoNerdFont-CondensedRegular.ttf
# MartianMono NF
# /home/avanti/.local/share/fonts/mj/dist/fonts/HTML-CSS/STIX-Web/otf/STIXMathJax_Symbols-Bold.otf
# STIX MathJax Symbols
# /usr/share/fonts/OTF/DroidSansMNerdFont-Regular.otf
# DroidSansM Nerd Font
# /usr/share/fonts/OTF/GeistMonoNerdFont-Regular.otf
# GeistMono NF
# /usr/share/fonts/noto/NotoSansTelugu-ExtraCondensedSemiBold.ttf
# Noto Sans Telugu
# /usr/share/fonts/OTF/FiraMonoNerdFontPropo-Bold.otf
# FiraMono Nerd Font Propo
# /usr/share/fonts/noto/NotoSansGunjalaGondi-Bold.ttf
# Noto Sans Gunjala Gondi
# /usr/share/fonts/noto/NotoSerifTamil-Condensed.ttf
# Noto Serif Tamil Condensed
# /usr/share/fonts/noto/NotoSansArabicUI-Bold.ttf
# Noto Sans Arabic UI
# /usr/share/fonts/noto/NotoSansThaiLooped-ExtraCondensedBold.ttf
# Noto Sans Thai Looped ExtraCondensed
# /usr/share/fonts/OTF/HasklugNerdFont-LightItalic.otf
# Hasklug Nerd Font
# /usr/share/fonts/TTF/AnonymiceProNerdFont-Regular.ttf
# AnonymicePro Nerd Font
# /usr/share/fonts/noto/NotoSansInscriptionalParthian-Regular.ttf
# Noto Sans Inscriptional Parthian
# /usr/share/fonts/noto/NotoSans-Condensed.ttf
# Noto Sans
# /usr/share/fonts/noto/NotoSansCham-Black.ttf
# Noto Sans Cham
# /usr/share/fonts/TTF/NotoSansMNerdFontMono-Medium.ttf
# NotoSansM NFM
# /usr/share/fonts/noto/NotoSerifTamil-SemiCondensedBlackItalic.ttf
# Noto Serif Tamil SemiCondensed
# /usr/share/fonts/noto/NotoSansThai-CondensedLight.ttf
# Noto Sans Thai
# /usr/share/fonts/TTF/NotoSerifNerdFontPropo-CondensedThin.ttf
# NotoSerif NFP
# /home/avanti/.local/share/fonts/mj/fonts/HTML-CSS/Neo-Euler/otf/NeoEulerMathJax_Symbols-Regular.otf
# Neo Euler
# /usr/share/fonts/noto/NotoSansBengaliUI-Condensed.ttf
# Noto Sans Bengali UI Condensed
# /usr/share/fonts/noto/NotoSerifTamil-CondensedBold.ttf
# Noto Serif Tamil Condensed
# /usr/share/fonts/TTF/M+1NerdFontPropo-Thin.ttf
# M+1 Nerd Font Propo
# /usr/share/fonts/TTF/IosevkaTermNerdFont-Oblique.ttf
# IosevkaTerm NF
# /usr/share/fonts/TTF/M+1CodeNerdFontPropo-Regular.ttf
# M+1Code Nerd Font Propo
# /usr/share/fonts/OTF/MonaspiceNeNerdFontMono-Bold.otf
# MonaspiceNe NFM
# /usr/share/fonts/OTF/HurmitNerdFontPropo-Italic.otf
# Hurmit Nerd Font Propo
# /usr/share/fonts/noto/NotoSerifKhmer-CondensedLight.ttf
# Noto Serif Khmer
# /usr/share/fonts/TTF/BlexMonoNerdFontPropo-Italic.ttf
# BlexMono Nerd Font Propo
# /usr/share/fonts/OTF/MonaspaceXenon-SemiBoldItalic.otf
# Monaspace Xenon
# /usr/share/fonts/noto/NotoSerifDevanagari-Medium.ttf
# Noto Serif Devanagari
# /usr/share/fonts/noto/NotoSansSinhala-ExtraCondensedLight.ttf
# Noto Sans Sinhala ExtraCondensed
# /usr/share/fonts/TTF/NotoSansMNerdFontPropo-Medium.ttf
# NotoSansM NFP
# /usr/share/fonts/noto/NotoSansMyanmar-ExtraCondensedSemiBold.ttf
# Noto Sans Myanmar ExtraCondensed
# /usr/share/fonts/noto/NotoSans-ExtraCondensedLightItalic.ttf
# Noto Sans
# /usr/share/fonts/noto/NotoSerifHebrew-CondensedSemiBold.ttf
# Noto Serif Hebrew
# /usr/share/fonts/TTF/BigBlueTerm437NerdFont-Regular.ttf
# BigBlueTerm437 Nerd Font
# /usr/share/fonts/noto/NotoSansLaoLooped-CondensedThin.ttf
# Noto Sans Lao Looped Condensed
# /home/avanti/.local/share/fonts/mj/dist/fonts/HTML-CSS/STIX-Web/otf/STIXMathJax_Normal-Bold.otf
# STIX MathJax Normal
# /usr/share/fonts/TTF/ArimoNerdFontPropo-Bold.ttf
# Arimo Nerd Font Propo
# /usr/share/fonts/TTF/ZedMonoNerdFontMono-Extended.ttf
# ZedMono NFM
# /usr/share/fonts/noto/NotoSansSinhalaUI-Condensed.ttf
# Noto Sans Sinhala UI Condensed
# /usr/share/fonts/noto/NotoSerif-SemiCondensedExtraLightItalic.ttf
# Noto Serif
# /usr/share/fonts/noto/NotoSansKannada-ExtraCondensedThin.ttf
# Noto Sans Kannada
# /usr/share/fonts/TTF/NotoSansNerdFont-Medium.ttf
# NotoSans NF
# /usr/share/fonts/TTF/M+CodeLat60NerdFontPropo-Bold.ttf
# M+CodeLat60 Nerd Font Propo
# /usr/share/fonts/noto/NotoSerifGeorgian-ExtraCondensedBold.ttf
# Noto Serif Georgian
# /usr/share/fonts/noto/NotoSansGujarati-SemiCondensedThin.ttf
# Noto Sans Gujarati
# /usr/share/fonts/TTF/CaskaydiaCoveNerdFontPropo-Bold.ttf
# CaskaydiaCove NFP
# /usr/share/fonts/OTF/MonaspiceKrNerdFontPropo-Medium.otf
# MonaspiceKr NFP
# /home/avanti/.local/share/fonts/mj/dist/fonts/HTML-CSS/TeX/otf/MathJax_Main-Regular.otf
# MathJax_Main
# /usr/share/fonts/wps-fonts/trebuc.ttf
# Trebuchet MS
# /usr/share/fonts/OTF/MonaspaceKrypton-WideMedium.otf
# Monaspace Krypton
# /usr/share/fonts/TTF/ZedMonoNerdFontMono-ExtendedExtraBoldOblique.ttf
# ZedMono NFM
# /usr/share/fonts/noto/NotoSansTelugu-CondensedLight.ttf
# Noto Sans Telugu
# /home/avanti/.local/share/fonts/latex/english/Sans/HelveticaBold.ttf
# Helvetica
# /usr/share/fonts/noto/NotoSansTamil-CondensedBlack.ttf
# Noto Sans Tamil Condensed
# /usr/share/fonts/TTF/ZedMonoNerdFontMono-Medium.ttf
# ZedMono NFM
# /usr/share/fonts/wps-fonts/times.ttf
# Times New Roman
# /usr/share/fonts/noto/NotoSansGeorgian-SemiCondensedThin.ttf
# Noto Sans Georgian
# /usr/share/fonts/noto/NotoSansDevanagariUI-SemiCondensed.ttf
# Noto Sans Devanagari UI SemiCondensed
# /usr/share/fonts/noto/NotoSans-SemiBold.ttf
# Noto Sans
# /usr/share/fonts/TTF/MononokiNerdFontMono-Regular.ttf
# Mononoki Nerd Font Mono
# /usr/share/fonts/TTF/SauceCodeProNerdFont-BlackItalic.ttf
# SauceCodePro NF
# /usr/share/fonts/noto/NotoSerifArmenian-CondensedBlack.ttf
# Noto Serif Armenian
# /home/avanti/.local/share/fonts/OperatorMono/OperatorMono-Medium.otf
# Operator Mono
# /usr/share/fonts/noto/NotoSerifMyanmar-SemiCondensedMedium.ttf
# Noto Serif Myanmar SemiCondensed
# /usr/share/fonts/TTF/MesloLGSDZNerdFontMono-Bold.ttf
# MesloLGSDZ Nerd Font Mono
# /usr/share/fonts/noto/NotoSansMeeteiMayek-Thin.ttf
# Noto Sans Meetei Mayek
# /usr/share/fonts/noto/NotoKufiArabic-Bold.ttf
# Noto Kufi Arabic
# /usr/share/fonts/noto/NotoSans-ExtraCondensedSemiBoldItalic.ttf
# Noto Sans
# /usr/share/fonts/noto/NotoRashiHebrew-Medium.ttf
# Noto Rashi Hebrew
# /home/avanti/.local/share/fonts/mj/dist/fonts/HTML-CSS/STIX-Web/otf/STIXMathJax_DoubleStruck-BoldItalic.otf
# STIX MathJax DoubleStruck
# /usr/share/fonts/TTF/M+1NerdFont-Regular.ttf
# M+1 Nerd Font
# /usr/share/fonts/noto/NotoSerifBengali-SemiCondensedLight.ttf
# Noto Serif Bengali
# /usr/share/fonts/OTF/HasklugNerdFontMono-ExtraLight.otf
# Hasklug Nerd Font Mono
# /home/avanti/.local/share/fonts/mj/fonts/HTML-CSS/Asana-Math/otf/AsanaMathJax_Size1-Regular.otf
# Asana Math
# /usr/share/fonts/noto/NotoSansMalayalamUI-ExtraCondensedMedium.ttf
# Noto Sans Malayalam UI ExtraCondensed
# /usr/share/fonts/TTF/NotoSansMNerdFont-SemiCondensedBold.ttf
# NotoSansM NF
# /usr/share/fonts/TTF/NotoSansNerdFont-ExtraLight.ttf
# NotoSans NF
# /usr/share/fonts/TTF/IosevkaTermNerdFontMono-LightItalic.ttf
# IosevkaTerm NFM
# /usr/share/fonts/noto/NotoSerifKhmer-SemiCondensedBlack.ttf
# Noto Serif Khmer
# /usr/share/fonts/TTF/LilexNerdFontPropo-BoldItalic.ttf
# Lilex Nerd Font Propo
# /usr/share/fonts/noto/NotoSerifMyanmar-ExtraBold.ttf
# Noto Serif Myanmar
# /usr/share/fonts/OTF/HurmitNerdFontPropo-Bold.otf
# Hurmit Nerd Font Propo
# /usr/share/fonts/noto/NotoSerifArmenian-CondensedBold.ttf
# Noto Serif Armenian
# /usr/share/fonts/TTF/FiraCodeNerdFont-Retina.ttf
# FiraCode Nerd Font
# /usr/share/fonts/OTF/MonaspaceNeon-SemiWideExtraLightItalic.otf
# Monaspace Neon
# /usr/share/fonts/noto/NotoSansSoraSompeng-Bold.ttf
# Noto Sans Sora Sompeng
# /usr/share/fonts/TTF/3270NerdFontPropo-Condensed.ttf
# 3270 Nerd Font Propo
# /usr/share/fonts/noto-cjk/NotoSerifCJK-Black.ttc
# Noto Serif CJK JP
# /usr/share/fonts/TTF/iMWritingQuatNerdFontPropo-Bold.ttf
# iMWritingQuat Nerd Font Propo
# /usr/share/fonts/noto/NotoSansTamil-Medium.ttf
# Noto Sans Tamil
# /usr/share/fonts/OTF/lmsansquot8-oblique.otf
# LMSansQuot8
# /usr/share/fonts/TTF/JetBrainsMonoNLNerdFont-Bold.ttf
# JetBrainsMonoNL NF
# /usr/share/fonts/TTF/JetBrainsMonoNerdFont-Regular.ttf
# JetBrainsMono NF
# /usr/share/fonts/noto/NotoSerifTamil-CondensedBlackItalic.ttf
# Noto Serif Tamil Condensed
# /usr/share/fonts/noto/NotoSansBengaliUI-Black.ttf
# Noto Sans Bengali UI
# /usr/share/fonts/noto/NotoSansMalayalamUI-SemiCondensedSemiBold.ttf
# Noto Sans Malayalam UI SemiCondensed
# /usr/share/fonts/noto/NotoSansMalayalam-ExtraCondensedMedium.ttf
# Noto Sans Malayalam ExtraCondensed
# /usr/share/fonts/TTF/FiraCode-Regular.ttf
# Fira Code
# /usr/share/fonts/noto/NotoSansHanifiRohingya-Bold.ttf
# Noto Sans Hanifi Rohingya
# /home/avanti/.local/share/fonts/lxgw/LXGWNeoZhiSongScreenFull.ttf
# LXGW Neo ZhiSong Screen Full
# /usr/share/fonts/noto/NotoSans-SemiBoldItalic.ttf
# Noto Sans
# /usr/share/fonts/TTF/NotoSerifNerdFontPropo-CondensedSemiBold.ttf
# NotoSerif NFP
# /usr/share/fonts/noto/NotoSansKannada-CondensedMedium.ttf
# Noto Sans Kannada
# /home/avanti/.local/share/fonts/mj/fonts/HTML-CSS/TeX/otf/MathJax_Size3-Regular.otf
# MathJax_Size3
# /usr/share/fonts/gnu-free/FreeSerifItalic.otf
# FreeSerif
# /home/avanti/.local/share/fonts/latex/chinese/宋体/AR-PL-SungtiL-GB.ttf
# AR PL SungtiL GB
# /usr/share/fonts/OTF/MonaspiceRnNerdFont-MediumItalic.otf
# MonaspiceRn NF
# /usr/share/fonts/noto/NotoSansArabic-ExtraCondensedLight.ttf
# Noto Sans Arabic
# /usr/share/fonts/noto/NotoSerifArmenian-ExtraCondensedSemiBold.ttf
# Noto Serif Armenian
# /usr/share/fonts/TTF/InconsolataNerdFontPropo-Bold.ttf
# Inconsolata Nerd Font Propo
# /usr/share/fonts/OTF/MonaspaceArgon-SemiWideItalic.otf
# Monaspace Argon
# /usr/share/fonts/OTF/MonaspiceKrNerdFontMono-Medium.otf
# MonaspiceKr NFM
# /usr/share/fonts/OTF/HasklugNerdFontPropo-Italic.otf
# Hasklug Nerd Font Propo
# /usr/share/fonts/noto/NotoSerifKhmer-Bold.ttf
# Noto Serif Khmer
# /usr/share/fonts/OTF/MonaspaceRadon-WideBold.otf
# Monaspace Radon
# /usr/share/fonts/OTF/HasklugNerdFontMono-BlackItalic.otf
# Hasklug Nerd Font Mono
# /usr/share/fonts/noto/NotoSansEthiopic-CondensedBlack.ttf
# Noto Sans Ethiopic Condensed
# /usr/share/fonts/noto/NotoSansThaiLooped-SemiCondensedExtraBold.ttf
# Noto Sans Thai Looped SemiCondensed
# /usr/share/fonts/TTF/NotoSansNerdFontPropo-SemiCondensedLight.ttf
# NotoSans NFP
# /usr/share/fonts/TTF/LilexNerdFontMono-ThinItalic.ttf
# Lilex Nerd Font Mono
# /usr/share/fonts/OTF/MonaspaceRadon-WideMedium.otf
# Monaspace Radon
# /usr/share/fonts/OTF/MonaspiceArNerdFont-Regular.otf
# MonaspiceAr NF
# /usr/share/fonts/noto/NotoSansThaana-Thin.ttf
# Noto Sans Thaana
# /usr/share/fonts/noto/NotoSerifDisplay-ThinItalic.ttf
# Noto Serif Display
# /usr/share/fonts/TTF/InconsolataLGCNerdFontPropo-Italic.ttf
# Inconsolata LGC Nerd Font Propo
# /usr/share/fonts/noto/NotoSansKannada-CondensedThin.ttf
# Noto Sans Kannada
# /usr/share/fonts/noto/NotoSerifLao-SemiCondensedBlack.ttf
# Noto Serif Lao SemiCondensed
# /usr/share/fonts/TTF/M+CodeLat60NerdFontMono-Regular.ttf
# M+CodeLat60 Nerd Font Mono
# /usr/share/fonts/noto/NotoSansSinhalaUI-ExtraCondensed.ttf
# Noto Sans Sinhala UI ExtraCondensed
# /usr/share/fonts/noto/NotoSansGujaratiUI-CondensedBold.ttf
# Noto Sans Gujarati UI
# /usr/share/fonts/TTF/RecMonoCasualNerdFont-BoldItalic.ttf
# RecMonoCasual Nerd Font
# /usr/share/fonts/noto/NotoSansTifinaghAgrawImazighen-Regular.ttf
# Noto Sans Tifinagh Agraw Imazighen
# /usr/share/fonts/noto/NotoSansMalayalamUI-SemiCondensed.ttf
# Noto Sans Malayalam UI SemiCondensed
# /usr/share/fonts/TTF/IosevkaNerdFontMono-MediumOblique.ttf
# Iosevka NFM
# /usr/share/fonts/noto/NotoSerif-ExtraBold.ttf
# Noto Serif
# /usr/share/fonts/TTF/ZedMonoNerdFontPropo-Bold.ttf
# ZedMono NFP
# /usr/share/fonts/liberation/LiberationSerif-Bold.ttf
# Liberation Serif
# /usr/share/fonts/TTF/SauceCodeProNerdFontPropo-Medium.ttf
# SauceCodePro NFP
# /usr/share/fonts/TTF/NotoSansMNerdFont-ExtraCondensedLight.ttf
# NotoSansM NF
# /usr/share/fonts/TTF/SauceCodeProNerdFont-Medium.ttf
# SauceCodePro NF
# /usr/share/fonts/noto/NotoNaskhArabic-SemiBold.ttf
# Noto Naskh Arabic
# /usr/share/fonts/noto/NotoSerif-ExtraCondensedLight.ttf
# Noto Serif
# /usr/share/fonts/noto/NotoSerifMakasar-Regular.ttf
# Noto Serif Makasar
# /usr/share/fonts/noto/NotoSerifTamil-Thin.ttf
# Noto Serif Tamil
# /usr/share/fonts/noto/NotoSansGujaratiUI-ExtraCondensedLight.ttf
# Noto Sans Gujarati UI
# /usr/share/fonts/noto/NotoSerifArmenian-SemiCondensedExtraBold.ttf
# Noto Serif Armenian
# /usr/share/fonts/TTF/MesloLGLNerdFontPropo-Italic.ttf
# MesloLGL Nerd Font Propo
# /usr/share/fonts/OTF/OpenDyslexicMNerdFontPropo-Regular.otf
# OpenDyslexicM Nerd Font Propo
# /usr/share/fonts/TTF/RecMonoDuotoneNerdFontPropo-Italic.ttf
# RecMonoDuotone Nerd Font Propo
# /usr/share/fonts/noto/NotoSerifDisplay-CondensedThin.ttf
# Noto Serif Display Condensed
# /home/avanti/.local/share/fonts/mj/fonts/HTML-CSS/TeX/otf/MathJax_Fraktur-Bold.otf
# MathJax_Fraktur
# /home/avanti/.local/share/fonts/mj/fonts/HTML-CSS/STIX-Web/otf/STIXMathJax_Monospace-Regular.otf
# STIX MathJax Monospace
# /usr/share/fonts/TTF/NotoSerifNerdFontPropo-Regular.ttf
# NotoSerif NFP
# /usr/share/fonts/noto/NotoSansMalayalam-SemiCondensedMedium.ttf
# Noto Sans Malayalam SemiCondensed
# /usr/share/fonts/TTF/Monaspace Krypton Var.ttf
# Monaspace Krypton Var
# ...
# Courier New
# /usr/share/fonts/TTF/FantasqueSansMNerdFontPropo-BoldItalic.ttf
# FantasqueSansM Nerd Font Propo
# /usr/share/fonts/TTF/ZedMonoNerdFontPropo-LightOblique.ttf
# ZedMono NFP
# /usr/share/fonts/noto/NotoSansArabic-SemiBold.ttf
# Noto Sans Arabic
# /usr/share/fonts/noto/NotoSansMalayalam-Black.ttf
# Noto Sans Malayalam
# /home/avanti/.local/share/fonts/fangzheng/方正康体_GBK.ttf
# FZKangTi-S07
# /usr/share/fonts/TTF/NotoSerifNerdFont-CondensedExtraBold.ttf
# NotoSerif NF
# /usr/share/fonts/TTF/RecMonoSmCasualNerdFontMono-Bold.ttf
# RecMonoSmCasual Nerd Font Mono
# /usr/share/fonts/noto/NotoSansGeorgian-CondensedMedium.ttf
# Noto Sans Georgian
# /usr/share/fonts/noto/NotoSerifGeorgian-ExtraCondensedExtraLight.ttf
# Noto Serif Georgian
# /usr/share/fonts/TTF/MartianMonoNerdFontMono-CondensedMedium.ttf
# MartianMono NFM
# /usr/share/fonts/OTF/MonaspaceNeon-SemiWideExtraBold.otf
# Monaspace Neon
# /usr/share/fonts/OTF/MonaspaceXenon-SemiWideMediumItalic.otf
# Monaspace Xenon
# /usr/share/fonts/TTF/IosevkaNerdFontPropo-ExtraLightItalic.ttf
# Iosevka NFP
# /usr/share/fonts/noto/NotoSansThaiLooped-ExtraCondensedThin.ttf
# Noto Sans Thai Looped ExtraCondensed
# /usr/share/fonts/noto/NotoSerifArmenian-ExtraCondensedBold.ttf
# Noto Serif Armenian
# /usr/share/fonts/Adwaita/AdwaitaMono-Regular.ttf
# Adwaita Mono
# /usr/share/fonts/OTF/GeistMonoNerdFontMono-Bold.otf
# GeistMono NFM
# /usr/share/fonts/gnu-free/FreeMonoBold.otf
# FreeMono
# /usr/share/fonts/TTF/SauceCodeProNerdFontMono-SemiBold.ttf
# SauceCodePro NFM
# /usr/share/fonts/OTF/MonaspiceArNerdFont-Bold.otf
# MonaspiceAr NF
# /usr/share/fonts/TTF/CaskaydiaMonoNerdFontMono-ExtraLightItalic.ttf
# CaskaydiaMono NFM
# /usr/share/fonts/TTF/NotoSerifNerdFont-SemiCondensedSemiBold.ttf
# NotoSerif NF
# /usr/share/fonts/OTF/CommitMonoNerdFontMono-BoldItalic.otf
# CommitMono Nerd Font Mono
# /usr/share/fonts/TTF/NotoSansNerdFont-ExtraBold.ttf
# NotoSans NF
# /usr/share/fonts/TTF/NotoSerifNerdFont-SemiCondensedExtraBoldItalic.ttf
# NotoSerif NF
# /usr/share/fonts/TTF/SauceCodeProNerdFontPropo-Light.ttf
# SauceCodePro NFP
# /usr/share/fonts/noto/NotoSansThaiLooped-Medium.ttf
# Noto Sans Thai Looped
# /usr/share/fonts/noto/NotoSerifDevanagari-CondensedMedium.ttf
# Noto Serif Devanagari
# /usr/share/fonts/noto/NotoSerifArmenian-SemiCondensedLight.ttf
# Noto Serif Armenian
# /usr/share/fonts/TTF/LilexNerdFontMono-ExtraLight.ttf
# Lilex Nerd Font Mono
# /usr/share/fonts/noto/NotoSerifDisplay-Black.ttf
# Noto Serif Display
# /usr/share/fonts/TTF/NotoSansMNerdFont-CondensedRegular.ttf
# NotoSansM NF
# /usr/share/fonts/noto/NotoSansKannadaUI-Black.ttf
# Noto Sans Kannada UI
# /home/avanti/.local/share/fonts/mj/fonts/HTML-CSS/STIX-Web/otf/STIXMathJax_Misc-BoldItalic.otf
# STIX MathJax Misc
# /usr/share/fonts/OTF/MonaspaceKrypton-SemiWideExtraBoldItalic.otf
# Monaspace Krypton
# /usr/share/fonts/TTF/RobotoMonoNerdFontMono-Thin.ttf
# RobotoMono Nerd Font Mono
# /usr/share/fonts/OTF/MonaspaceNeon-LightItalic.otf
# Monaspace Neon
# /usr/share/fonts/noto/NotoSansGeorgian-ExtraBold.ttf
# Noto Sans Georgian
# /usr/share/fonts/noto/NotoSansMalayalamUI-SemiCondensedExtraBold.ttf
# Noto Sans Malayalam UI SemiCondensed
# /usr/share/fonts/TTF/InconsolataLGCNerdFontMono-BoldItalic.ttf
# Inconsolata LGC Nerd Font Mono
# /usr/share/fonts/OTF/MonaspiceRnNerdFontMono-Italic.otf
# MonaspiceRn NFM
# /home/avanti/.local/share/fonts/OperatorMonoLig/OperatorMonoLig-Light.otf
# Operator Mono Lig
# /home/avanti/.local/share/fonts/puhuiti3/AlibabaPuHuiTi-3-75-SemiBold/AlibabaPuHuiTi-3-75-SemiBold.otf
# Alibaba PuHuiTi 3.0
# /usr/share/fonts/TTF/M+1CodeNerdFontMono-Medium.ttf
# M+1Code Nerd Font Mono
# /home/avanti/.local/share/fonts/ysabeau/YsabeauInfant-Medium.otf
# Ysabeau Infant
# /usr/share/fonts/TTF/IosevkaTermSlabNerdFont-BoldOblique.ttf
# IosevkaTermSlab NF
# /usr/share/fonts/noto/NotoSansGujarati-Black.ttf
# Noto Sans Gujarati
# /usr/share/fonts/TTF/GohuFontuni14NerdFontMono-Regular.ttf
# GohuFont uni14 Nerd Font Mono
# /usr/share/fonts/noto/NotoSansMyanmar-Regular.ttf
# Noto Sans Myanmar
# /usr/share/fonts/OTF/MonaspiceNeNerdFontPropo-LightItalic.otf
# MonaspiceNe NFP
# /usr/share/fonts/TTF/M+CodeLat60NerdFont-Light.ttf
# M+CodeLat60 Nerd Font
# /usr/share/fonts/TTF/CaskaydiaMonoNerdFont-LightItalic.ttf
# CaskaydiaMono NF
# /usr/share/fonts/liberation/LiberationMono-Italic.ttf
# Liberation Mono
# /usr/share/fonts/noto/NotoSansKannada-Thin.ttf
# Noto Sans Kannada
# /usr/share/fonts/wps-fonts/corbell.ttf
# Corbel
# /usr/share/fonts/TTF/NotoSansMNerdFontMono-CondensedRegular.ttf
# NotoSansM NFM
# /usr/share/fonts/noto/NotoSansDevanagariUI-Thin.ttf
# Noto Sans Devanagari UI
# /usr/share/fonts/TTF/CaskaydiaCoveNerdFont-SemiLightItalic.ttf
# CaskaydiaCove NF
# /usr/share/fonts/gnu-free/FreeSans.otf
# FreeSans
# /usr/share/fonts/noto/NotoSerifGeorgian-ExtraCondensedLight.ttf
# Noto Serif Georgian
# /home/avanti/.local/share/fonts/ebgaramond/EBGaramond-Bold.ttf
# EB Garamond
# /usr/share/fonts/TTF/NotoSansNerdFontPropo-CondensedBlackItalic.ttf
# NotoSans NFP
# /usr/share/fonts/TTF/NotoSansNerdFont-ExtraCondensedLight.ttf
# NotoSans NF
# /usr/share/fonts/noto/NotoSerifKhmer-CondensedMedium.ttf
# Noto Serif Khmer
# /usr/share/fonts/OTF/MonaspaceKrypton-SemiWideLightItalic.otf
# Monaspace Krypton
# /usr/share/fonts/noto/NotoSans-SemiCondensedExtraBold.ttf
# Noto Sans
# /usr/share/fonts/adobe-source-han-serif/SourceHanSerifCN-Regular.otf
# Source Han Serif CN
# /usr/share/fonts/wps-fonts/gadugi.ttf
# Gadugi
# /usr/share/fonts/noto/NotoSerifDisplay-Italic.ttf
# Noto Serif Display
# /usr/share/fonts/TTF/NotoSansNerdFontPropo-CondensedThin.ttf
# NotoSans NFP
# /usr/share/fonts/TTF/FiraCodeNerdFontPropo-Bold.ttf
# FiraCode Nerd Font Propo
# /usr/share/fonts/noto/NotoSansSymbols-SemiBold.ttf
# Noto Sans Symbols
# /usr/share/fonts/TTF/JetBrainsMonoNerdFontPropo-ThinItalic.ttf
# JetBrainsMono NFP
# /usr/share/fonts/noto/NotoSansTamilUI-ExtraCondensedBlack.ttf
# Noto Sans Tamil UI ExtraCondensed
# /usr/share/fonts/TTF/JetBrainsMonoNLNerdFontPropo-ThinItalic.ttf
# JetBrainsMonoNL NFP
# /home/avanti/.local/share/fonts/ebgaramond/EBGaramond-BoldItalic.ttf
# EB Garamond
# /usr/share/fonts/TTF/JetBrainsMonoNLNerdFont-Light.ttf
# JetBrainsMonoNL NF
# /usr/share/fonts/noto/NotoSerifArmenian-ExtraCondensedMedium.ttf
# Noto Serif Armenian
# /usr/share/fonts/OTF/MonaspiceXeNerdFontMono-MediumItalic.otf
# MonaspiceXe NFM
# /usr/share/fonts/noto/NotoSerifDisplay-SemiBold.ttf
# Noto Serif Display
# /usr/share/fonts/TTF/BlexMonoNerdFontPropo-ExtraLightItalic.ttf
# BlexMono Nerd Font Propo
# /usr/share/fonts/OTF/CodeNewRomanNerdFont-Regular.otf
# CodeNewRoman Nerd Font
# /usr/share/fonts/noto/NotoSansKhudawadi-Regular.ttf
# Noto Sans Khudawadi
# /usr/share/fonts/noto/NotoSerifBengali-Light.ttf
# Noto Serif Bengali
# /usr/share/fonts/noto/NotoSerifLao-SemiCondensedSemiBold.ttf
# Noto Serif Lao SemiCondensed
# /usr/share/fonts/TTF/NotoSansNerdFont-ExtraBoldItalic.ttf
# NotoSans NF
# /usr/share/fonts/noto/NotoSansBengali-ExtraCondensedLight.ttf
# Noto Sans Bengali
# /usr/share/fonts/OTF/MonaspiceRnNerdFontPropo-MediumItalic.otf
# MonaspiceRn NFP
# /home/avanti/.local/share/fonts/mj/fonts/HTML-CSS/Gyre-Pagella/otf/GyrePagellaMathJax_Size4-Regular.otf
# TeX Gyre Pagella Math
# /usr/share/fonts/TTF/IosevkaTermNerdFontPropo-Italic.ttf
# IosevkaTerm NFP
# /usr/share/fonts/noto/NotoSansMalayalam-SemiCondensedExtraLight.ttf
# Noto Sans Malayalam SemiCondensed
# /usr/share/fonts/TTF/NotoSansMNerdFontMono-SemiCondensedExtraLight.ttf
# NotoSansM NFM
# /usr/share/fonts/noto/NotoSansMalayalam-ExtraLight.ttf
# Noto Sans Malayalam
# /usr/share/fonts/noto/NotoSerifLao-SemiCondensedLight.ttf
# Noto Serif Lao SemiCondensed
# /usr/share/fonts/OTF/HasklugNerdFont-Black.otf
# Hasklug Nerd Font
# /usr/share/fonts/OTF/CommitMonoNerdFont-BoldItalic.otf
# CommitMono Nerd Font
# /home/avanti/.local/share/fonts/mj/fonts/HTML-CSS/TeX/otf/MathJax_Main-Regular.otf
# MathJax_Main
# /usr/share/fonts/noto/NotoSansGujaratiUI-ExtraCondensedExtraLight.ttf
# Noto Sans Gujarati UI
# /usr/share/fonts/TTF/IosevkaTermSlabNerdFontPropo-Italic.ttf
# IosevkaTermSlab NFP
# /home/avanti/.local/share/fonts/puhuiti3/AlibabaPuHuiTi-3-35-Thin/AlibabaPuHuiTi-3-35-Thin.otf
# Alibaba PuHuiTi 3.0
# /usr/share/fonts/noto/NotoSerif-CondensedBlack.ttf
# Noto Serif
# /usr/share/fonts/noto/NotoSansMono-Light.ttf
# Noto Sans Mono
# /usr/share/fonts/TTF/NotoSansNerdFontPropo-SemiCondensedItalic.ttf
# NotoSans NFP
# /usr/share/fonts/noto/NotoSerif-CondensedThin.ttf
# Noto Serif
# /usr/share/fonts/noto/NotoSansMalayalam-CondensedBlack.ttf
# Noto Sans Malayalam Condensed
# /usr/share/fonts/OTF/MonaspaceArgon-SemiBold.otf
# Monaspace Argon
# /home/avanti/.local/share/fonts/ysabeau/YsabeauInfant-Italic.otf
# Ysabeau Infant
# /usr/share/fonts/TTF/IosevkaNerdFontMono-Heavy.ttf
# Iosevka NFM
# /usr/share/fonts/TTF/NotoSerifNerdFont-CondensedExtraLightItalic.ttf
# NotoSerif NF
# /usr/share/fonts/TTF/FiraCode-Medium.ttf
# Fira Code
# /usr/share/fonts/noto/NotoSansBengali-SemiBold.ttf
# Noto Sans Bengali
# /usr/share/fonts/noto/NotoSansGujaratiUI-ExtraCondensedBlack.ttf
# Noto Sans Gujarati UI
# /usr/share/fonts/noto/NotoSerifKhitanSmallScript-Regular.ttf
# Noto Serif Khitan Small Script
# /usr/share/fonts/noto/NotoSansCanadianAboriginal-Black.ttf
# Noto Sans Canadian Aboriginal
# /usr/share/fonts/OTF/MonaspaceRadon-SemiWideBoldItalic.otf
# Monaspace Radon
# /usr/share/fonts/wps-fonts/sylfaen.ttf
# Sylfaen
# /usr/share/fonts/TTF/LiterationSansNerdFontPropo-Regular.ttf
# LiterationSans Nerd Font Propo
# /usr/share/fonts/OTF/lmmonolt10-bold.otf
# LMMonoLt10
# /usr/share/fonts/TTF/IntoneMonoNerdFont-BoldItalic.ttf
# IntoneMono NF
# /usr/share/fonts/OTF/MonaspiceRnNerdFontMono-BoldItalic.otf
# MonaspiceRn NFM
# /usr/share/fonts/noto/NotoSansHebrew-ExtraLight.ttf
# Noto Sans Hebrew
# /usr/share/fonts/noto/NotoSansMalayalam-CondensedSemiBold.ttf
# Noto Sans Malayalam Condensed
# /usr/share/fonts/TTF/MesloLGMDZNerdFontPropo-Regular.ttf
# MesloLGMDZ Nerd Font Propo
# /usr/share/fonts/TTF/IosevkaTermSlabNerdFont-MediumOblique.ttf
# IosevkaTermSlab NF
# /usr/share/fonts/TTF/M+CodeLat50NerdFont-ExtraLight.ttf
# M+CodeLat50 Nerd Font
# /usr/share/fonts/noto/NotoSerifMyanmar-ExtraCondensed.ttf
# Noto Serif Myanmar ExtraCondensed
# /usr/share/fonts/noto/NotoSerifLao-ExtraCondensedSemiBold.ttf
# Noto Serif Lao ExtraCondensed
# /usr/share/fonts/TTF/VictorMonoNerdFontMono-MediumOblique.ttf
# VictorMono NFM
# /home/avanti/.local/share/fonts/OperatorMonoLig2/OperatorMonoSSmLig-BookItalic.otf
# Operator Mono SSm Lig
# /usr/share/fonts/OTF/CommitMonoNerdFontMono-Regular.otf
# CommitMono Nerd Font Mono
# /usr/share/fonts/TTF/IosevkaTermSlabNerdFontPropo-BoldOblique.ttf
# IosevkaTermSlab NFP
# /usr/share/fonts/TTF/DejaVuSansMNerdFontMono-Oblique.ttf
# DejaVuSansM Nerd Font Mono
# /usr/share/fonts/noto/NotoSansTelugu-Medium.ttf
# Noto Sans Telugu
# /usr/share/fonts/OTF/MonaspaceNeon-ExtraBold.otf
# Monaspace Neon
# /usr/share/fonts/OTF/MonaspaceXenon-WideExtraLightItalic.otf
# Monaspace Xenon
# /usr/share/fonts/TTF/MonoidNerdFontPropo-Retina.ttf
# Monoid Nerd Font Propo
# /usr/share/fonts/noto/NotoSerifArmenian-Condensed.ttf
# Noto Serif Armenian
# /usr/share/fonts/noto/NotoSansGeorgian-ExtraLight.ttf
# Noto Sans Georgian
# /usr/share/fonts/noto/NotoSansGeorgian-Bold.ttf
# Noto Sans Georgian
# /usr/share/fonts/noto/NotoSerif-BlackItalic.ttf
# Noto Serif
# /usr/share/fonts/OTF/MonaspaceKrypton-ExtraLight.otf
# Monaspace Krypton
# /usr/share/fonts/noto/NotoSerifDisplay-SemiCondensedLightItalic.ttf
# Noto Serif Display SemiCondensed
# /usr/share/fonts/TTF/CousineNerdFontPropo-Italic.ttf
# Cousine Nerd Font Propo
# /usr/share/fonts/noto/NotoSansDevanagariUI-Light.ttf
# Noto Sans Devanagari UI
# /usr/share/fonts/noto/NotoSerifArmenian-CondensedSemiBold.ttf
# Noto Serif Armenian
# /usr/share/fonts/TTF/iMWritingMonoNerdFontMono-BoldItalic.ttf
# iMWritingMono Nerd Font Mono
# /home/avanti/.local/share/fonts/OperatorMonoLig/OperatorMonoLig-BookItalic.otf
# Operator Mono Lig
# /usr/share/fonts/noto/NotoSansMath-Regular.ttf
# Noto Sans Math
# /usr/share/fonts/TTF/LiterationMonoNerdFontPropo-Regular.ttf
# LiterationMono Nerd Font Propo
# /usr/share/fonts/TTF/M+2NerdFont-Thin.ttf
# M+2 Nerd Font
# /usr/share/fonts/TTF/IntoneMonoNerdFont-Bold.ttf
# IntoneMono NF
# /home/avanti/.local/share/fonts/mj/dist/fonts/HTML-CSS/STIX-Web/otf/STIXMathJax_SansSerif-BoldItalic.otf
# STIX MathJax SansSerif
# /usr/share/fonts/TTF/CaskaydiaMonoNerdFont-SemiLight.ttf
# CaskaydiaMono NF
# /usr/share/fonts/TTF/RecMonoSmCasualNerdFont-Bold.ttf
# RecMonoSmCasual Nerd Font
# /usr/share/fonts/TTF/LektonNerdFontMono-Bold.ttf
# Lekton Nerd Font Mono
# /usr/share/fonts/TTF/3270NerdFontPropo-SemiCondensed.ttf
# 3270 Nerd Font Propo
# /usr/share/fonts/noto/NotoSansGujaratiUI-SemiCondensedExtraLight.ttf
# Noto Sans Gujarati UI
# /usr/share/fonts/TTF/NotoSansMNerdFontMono-SemiBold.ttf
# NotoSansM NFM
# /usr/share/fonts/noto/NotoSerifGeorgian-CondensedBold.ttf
# Noto Serif Georgian
# /usr/share/fonts/wps-fonts/cambriab.ttf
# Cambria
# /usr/share/fonts/noto/NotoSansGeorgian-ExtraCondensed.ttf
# Noto Sans Georgian
# /home/avanti/.local/share/fonts/ysabeau/YsabeauOffice-HairlineItalic.otf
# Ysabeau Office
# /usr/share/fonts/TTF/CaskaydiaMonoNerdFontMono-SemiLight.ttf
# CaskaydiaMono NFM
# /usr/share/fonts/noto/NotoSansTamil-SemiCondensedExtraLight.ttf
# Noto Sans Tamil SemiCondensed
# /usr/share/fonts/wps-fonts/LeelUIsl.ttf
# Leelawadee UI
# /usr/share/fonts/TTF/RecMonoLinearNerdFontPropo-Regular.ttf
# RecMonoLinear Nerd Font Propo
# /usr/share/fonts/noto/NotoSansKannada-SemiCondensedExtraBold.ttf
# Noto Sans Kannada
# /usr/share/fonts/TTF/SauceCodeProNerdFontMono-Italic.ttf
# SauceCodePro NFM
# /home/avanti/.local/share/fonts/mj/fonts/HTML-CSS/Neo-Euler/otf/NeoEulerMathJax_Size1-Regular.otf
# Neo Euler
# /usr/share/fonts/TTF/IosevkaTermNerdFontPropo-LightOblique.ttf
# IosevkaTerm NFP
# /usr/share/fonts/TTF/LiterationSerifNerdFontPropo-Italic.ttf
# LiterationSerif Nerd Font Propo
# /usr/share/fonts/TTF/JetBrainsMonoNerdFontPropo-Medium.ttf
# JetBrainsMono NFP
# /usr/share/fonts/TTF/TinosNerdFontPropo-Italic.ttf
# Tinos Nerd Font Propo
# /usr/share/fonts/noto/NotoSansSinhala-SemiCondensedExtraBold.ttf
# Noto Sans Sinhala SemiCondensed
# /home/avanti/.local/share/fonts/mj/dist/fonts/HTML-CSS/STIX-Web/otf/STIXMathJax_Main-Italic.otf
# STIX MathJax Main
# /usr/share/fonts/noto/NotoSerifEthiopic-SemiCondensedBlack.ttf
# Noto Serif Ethiopic SemiCondensed
# /home/avanti/.local/share/fonts/fangzheng/方正仿宋_GBK.ttf
# FZFangSong-Z02
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[3], line 8
#       4
#       5 print(f"共找到{len(font_paths)}个字体文件")
#       6 for path in font_paths:
#       7     font_prop = fm.FontProperties(fname=path)
# ----> 8     font_name = font_prop.get_name()
#       9     print(path)
#      10     print(font_name)
#      11
#
# File /usr/lib/python3.14/site-packages/matplotlib/font_manager.py:731, in FontProperties.get_name(self)
#     727 def get_name(self):
#     728     """
#     729     Return the name of the font that best matches the font properties.
#     730     """
# --> 731     return get_font(findfont(self)).family_name
#
# File /usr/lib/python3.14/site-packages/matplotlib/font_manager.py:1615, in get_font(font_filepaths, hinting_factor)
#    1612 if hinting_factor is None:
#    1613     hinting_factor = mpl.rcParams['text.hinting_factor']
# -> 1615 return _get_font(
#    1616     # must be a tuple to be cached
#    1617     paths,
#    1618     hinting_factor,
#    1619     _kerning_factor=mpl.rcParams['text.kerning_factor'],
#    1620     # also key on the thread ID to prevent segfaults with multi-threading
#    1621     thread_id=threading.get_ident()
#    1622 )
#
# File /usr/lib/python3.14/site-packages/matplotlib/font_manager.py:1557, in _get_font(font_filepaths, hinting_factor, _kerning_factor, thread_id)
#    1554 @lru_cache(64)
#    1555 def _get_font(font_filepaths, hinting_factor, *, _kerning_factor, thread_id):
#    1556     first_fontpath, *rest = font_filepaths
# -> 1557     return ft2font.FT2Font(
#    1558         first_fontpath, hinting_factor,
#    1559         _fallback_list=[
#    1560             ft2font.FT2Font(
#    1561                 fpath, hinting_factor,
#    1562                 _kerning_factor=_kerning_factor
#    1563             )
#    1564             for fpath in rest
#    1565         ],
#    1566         _kerning_factor=_kerning_factor
#    1567     )
#
# RuntimeError: Could not set the fontsize (invalid pixel size; error code 0x17)

# %%
import matplotlib.pyplot as plt
import matplotlib.ticker as ticker
import matplotlib.font_manager as fm
import numpy as np
import scipy.stats as st

zhisong = fm.FontEntry(fname="/home/avanti/Fonts/LXGW/LXGWNeoZhiSongScreenFull.ttf", name="LXGW Neo ZhiSong Screen Full")
fm.fontManager.ttflist.insert(0, zhisong)
plt.rcParams.update({
    'figure.figsize': (10, 5),
    'figure.labelsize': "30",
    'figure.titlesize': "30",
    'text.color': "#586e75",
    # 字体选项
    "font.family": "LXGW Neo ZhiSong Screen Full",
    "mathtext.fontset": 'cm',
    "font.size": 10,
    # 坐标轴选项
    "axes.grid": True,
    'axes.titlecolor': "#586e75",
    'axes.edgecolor': "#586e75",
    'axes.labelcolor': "#586e75",
    'axes.labelsize': '30',
    "axes.unicode_minus": True,
    'axes.formatter.use_mathtext': True,
    # 刻度选项
    'xtick.color': "#586e75",
    'ytick.color': "#586e75",
    "xtick.labelsize": "20",
    "ytick.labelsize": "20",
    # 保存选项
    'savefig.format': 'svg',
    'savefig.transparent': True,
    'savefig.bbox': "tight",
    # 图样
    'legend.fontsize': '18',
    'legend.title_fontsize': "20",
})

fig, axs = plt.subplots(1, 2, sharex=True, sharey=True)

with plt.style.context('Solarize_Light2'):
    fig.suptitle('这是全局标题$\\sin \\mathbf{\\theta} = \\boldsymbol{a}^2$', fontsize=16)

    x = np.linspace(0, 2 * np.pi, 100)
    axs[0].plot(x, np.sin(x), label="$\\sin$")
    axs[0].set_title('正弦函数')
    axs[0].legend(prop={"family": "Ysabeau Office"})
    axs[0].set_xlabel("横轴")
    axs[0].set_ylabel("纵轴")

    # axs[0].xaxis.set_major_locator(ticker.MultipleLocator(2))
    # axs[0].xaxis.set_minor_locator(ticker.MultipleLocator(0.5))
    axs[0].tick_params(axis='both', labelfontfamily="Ysabeau Office")

    axs[1].plot(x, np.sin(x), label=r"$\sin$函数")
    axs[1].set_title('sin function', fontfamily="Ysabeau Office", fontsize=20)
    axs[1].legend(prop={"size": "20", "family": "LXGW Neo ZhiSong Screen Full"})

    plt.show()
